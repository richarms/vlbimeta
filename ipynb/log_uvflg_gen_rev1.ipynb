# %% [markdown]
# # Generation of log and uvflg file from sensors
#
# Conditions for setting uvflg:
# - number of antennas locked on target is below quorum
# - target doesn't match VLBI catalogue target (i.e. when doing phase-up)
#
# Rev a:
# - uvflag file generation
#
# Rev b:
# - generating a log file containing exerpts from MeerKAT observation script log, as well as GPS-maser offset.
#
# Rev 1:
# - Cleaned up / documented as standalone version.

# %%
# Experiments

# n24l3, 1729171747
# n25l1, 1740055990
# em181a, 1740224791
# es116a, 1740943459

# %%
# Main parameters

# VLBI Experiment name (sets the observation catalogue file name)
exp_name = 'es116a'
# NARROWBAND observation RDB file corresponding to the experiment
obs_cbid = "1740943459"
# Station code
station_code = 'me'

# Log file options
log_script = True
log_sensors = True
# Set true for running while portal is offline
portal_offline = False

# Antenna quorum for validity conditions
quorum = 0.90
# Flag / log file time resolution, in seconds.
log_interval = 1  
# Sensor reporting interval, in seconds. 
sensor_interval = 60 

# Observation catalogue directory
cat_dir = '/home/kat/richarms/vlbi/catalogues/'
# Output directory for calibration files
log_dir = '/home/kat/richarms/vlbi/metadata/'
# Location to download rdb files
rdb_dir = '/home/kat/richarms/vlbi/rdb_files/'

# %%
# Imports and definitions

import numpy as np
import os.path
import requests
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from datetime import datetime, timedelta, timezone
from astropy.time import Time as ap_time
import katdal
import katpoint


def parse_vlbi_cat(vlbi_cat_fn, proc_buffer_sec=1, ref_ant=None):
    """ Parses the provided VLBI catalogue file and provides a list of scan parameters and
    a katpoint catalogue of unique targets in the observation. 

    Parameters
    ----------
    vlbi_cat_fn : string
        Location of text file containing observation scan information
    proc_buffer_sec : integer 
        Buffer time in seconds added before and after processing start and 
        stop time. 
    ref_ant : katpoint Antenna object
        Reference antenna for katpoint Catalogue

    Returns
    -------
    obs_params : Dictionary
        Dictionary with observation parameters.
    scan_params : list of dictionaries
        List of dictionaries with paramters for each scan.
    vlbi_cat : katpoint Catalogue object
        katpoint catalogue with unique targets to be observed.
        
    """
    # Read the VLBI catalogue file 
    with open(vlbi_cat_fn, 'r') as cat_file:
        csv_lines = [line for line in cat_file.readlines()]
    # Read header info
    header_lines = [line[1:].strip() for line in csv_lines if line.startswith('#')]
    hdr_keys, hdr_ch_key = ['EXPERIMENT', 'POL', 'CAL_PREFIX'], 'CH'
    obs_params = dict.fromkeys(hdr_keys)
    obs_params['CHANNELS'] = {}
    for line in header_lines:
        hdr_key, hdr_par = line.split(' ')[0], line.split(' ')[1:]
        if hdr_key in hdr_keys:
            obs_params[hdr_key] = ' '.join(hdr_par)
        elif line.startswith(hdr_ch_key):
            obs_params['CHANNELS'][hdr_key] = hdr_par
    # Create list of scan parameters
    scan_params = {}
    scan_lines = [line for line in csv_lines if not line.startswith('#')]
    for scan_line in scan_lines:
        # Scan name
        scan_name = scan_line.split(',')[-3].strip()
        # Datetime of scan start time
        start_time_str = scan_line.split(',')[-2].strip()
        start_time = datetime.strptime(start_time_str, '%Y-%m-%d %H:%M:%S.%f')
        start_time = start_time.replace(tzinfo=timezone.utc)
        # Start time for processing of scan
        start_time_proc = start_time - timedelta(seconds=proc_buffer_sec)  
        # Duration
        duration = int(scan_line.split(',')[-1])
        # Target name
        tgt_string = scan_line.split(',')[0].split('|')[0].strip()
        tgt_string = tgt_string[1:] if tgt_string.startswith('*') else tgt_string
        # Create a katpoint target line
        kp_target_ln = ', '.join([kp.strip(' ') for kp in scan_line.split(',')[:-3]]) 
        # Store scan parameters
        scan_params[scan_name] = {'target':tgt_string,
                                  'start_iso':scan_line.split(',')[-2],
                                  'start_ts':start_time.timestamp(),
                                  'duration':duration,
                                  'kp_tgt':katpoint.Target(kp_target_ln, antenna=ref_ant),
                                  'proc_start_iso':start_time_proc.strftime('%Y-%m-%dT%H:%M:%S.%f'),
                                  'proc_start_ts':start_time_proc.timestamp(),                               
                                  'proc_duration':duration+2*proc_buffer_sec}
    # Sort dictionary entries by scan start time
    sorted_params = sorted(scan_params.items(), key=lambda e:e[1]['start_ts'])
    scan_params = dict(sorted_params)
    # Create a katpoint catalogue for unique targets
    kp_target_list = []
    for scan_name, scan_pars in scan_params.items():
        if scan_pars['kp_tgt'] not in kp_target_list:
            kp_target_list.append(scan_pars['kp_tgt'])
    vlbi_cat = katpoint.Catalogue(kp_target_list, antenna=ref_ant)
    return obs_params, scan_params, vlbi_cat


def get_sensor(sensorname, start_time, end_time, timeout=100,
               store_url="http://portal.mkat.karoo.kat.ac.za/katstore/api/query"):
    """ Retrieves data from the CAM sensor database with an http request.
    
    Parameters
    ----------
    sensorname : string
        Name of the sensor to retrieve, e.g. 'm004_dig_l_band_rfcu_hpol_rf_power_in'
    start_time : unix timestamp
        Start time of sensor database search.
    end_time : unix timestamp
        End time of sensor database search.
    timeout : integer, optional
        Timeout time for http request, in seconds. (Default=100)
    store_url : string, optional
        URL of the desired sensor portal. (Default="http://portal.mkat.karoo.kat.ac.za/katstore/api/query")
        
    Returns
    -------
    times, values : array
        Retrieved timestamps and values of requested sensor.
        
    """
    params={'sensor': sensorname,  # name of the sensor.
            'start_time': start_time, # start time in sec
            'end_time': end_time, # end time in sec
            'limit':10000000}
    try:
        res = requests.get(store_url, params, timeout=timeout) # Submit the query
        res.raise_for_status()  # Raise exception on status errors
        # Data comes back as JSON with the correct mime type set so can be converted by Requests
        data_list = np.asarray([(r['sample_time'], r['value']) for r in res.json()['data']])
    except Exception as e:
        print("Failed to connect to %s: \n%s" % (store_url,e))
        data_list = np.array([])
    if (np.shape(data_list)[0] == 0):
        return (np.asarray([]), np.asarray([]))
    else:
        _t, _v = np.asarray(data_list[:,0], dtype=float), data_list[:,1] 
        return (_t, _v)


class text_file_man():
    """ Simple text file creation functions.
    """
    def __init__(self):
        """ Initialise file lines. """
        self.file_lines = []

    def add_line(self, line_string):
        """ Append provided string as line to file.
        """
        self.file_lines.append(line_string)

    def write_to_file(self, fn_out):
        """ Write all text lines out to provided file name. """
        with open(fn_out, 'w') as out_file:
            for line in self.file_lines:
                out_file.write(line)
                out_file.write('\n')

    def print_all(self):
        """ Print all text lines for inspection. """
        for line in self.file_lines:
            print(line)


def get_flagged_ranges(timestamps, data_valid):
    """ Return time periods where data is invalid as a list of start/stop timestamp tuples. 
    
    Parameters
    ----------
    timestamps : Numpy ndarray
        Array of unix time stamps corresponding to the data valid signal. 
    data_valid : Numpy boolean ndarray 
        Boolean array that is True if data is valid.
        
    Returns
    -------
    ts_rng : list of tuples
        List of (start timestamp, stop timestamp) indicating where data_valid is False.
    
    """
    # Find valid and invalid indices
    data_args = np.arange(len(data_valid))
    invalid_args = data_args[data_valid==0]
    if len(invalid_args)>1:
        # Find beginning/end of discontinuous arguments
        invalid_beg = invalid_args[np.r_[True, np.diff(invalid_args)>1]]
        invalid_end = invalid_args[np.r_[np.diff(invalid_args)>1, True]]
        # Create list of beginning/ending timestamp tuples
        ts_rng = []
        for ii_beg, ii_end in zip(invalid_beg, invalid_end):
            ts_rng.append((timestamps[ii_beg],timestamps[ii_end]))
    else:
        ts_rng = None
    return ts_rng


class log_manager():
    """ Functions for managing log creation. A log is represented by a list of entries. 
    Each entry is a dictionary that includes (i) a 'time' field with a datetime object 
    representing log entry time, (ii) a 'key' field with a string label indicating the 
    type of entry, and (iii) a 'line' field containing the line text.
    """
    
    def __init__(self):
        """ Initialise log """
        self.log = []

    def add_entry(self, log_entry):
        """ Add entry to log. """
        self.log.append(log_entry)

    def get_logtime(self, ii_entry):
        """ Return time at specified entry index """
        return self.log[ii_entry]['time']

    def sort_entries(self):
        """ Sort entries by log entry time. """
        # Sort by unix timestamp
        sort_fcn = lambda e : e['time'].timestamp()
        self.log.sort(key=sort_fcn)
        #sorted_entries = sorted(self.log.items(), key=lambda e:e[1]['time'].timestamp())
        #self.log = dict(sorted_entries)

    def print_log(self):
        """ Print log. """
        for log_entry in self.log:
            # Set output format
            log_time = log_entry['time'].isoformat(sep=' ', timespec='milliseconds')
            # Truncate tzinfo
            log_time = log_time.split('+')[0]
            print(log_time, log_entry['key'], log_entry['line'])

    def write_to_file(self, fn_out):
        """ Write all text lines to specified file. """
        with open(fn_out, 'w') as out_file:
            for log_entry in self.log:
                # Set output format
                log_time = log_entry['time'].isoformat(sep=' ', timespec='milliseconds')
                # Truncate tzinfo
                log_time = log_time.split('+')[0]
                file_line = ' '.join([log_time, log_entry['key'], log_entry['line']])
                out_file.write(file_line)
                out_file.write('\n')

# %%
# Load RDB file and set parameters

# Set RDB address and file name
addr_rdb = 'http://archive-gw-1.kat.ac.za/'+obs_cbid+'/'+obs_cbid+'_sdp_l0.full.rdb'
fn_rdb = rdb_dir+obs_cbid+'_sdp_l0.full.rdb'
# Download RDB file
if not os.path.exists(fn_rdb):
    # !wget -P $rdb_dir $addr_rdb

# Open rdb file and read calibration solutions.
d = katdal.open(fn_rdb)
ant_names = [ant.name for ant in d.ants]
n_ants = len(ant_names)
pols = d.source.telstate['cal_pol_ordering']
obs_start_time = d.start_time.secs
obs_end_time = d.end_time.secs

# Load and parse observation VLBI catalogue
vlbi_cat_file = 'vlbi_cat_{}.csv'.format(exp_name)
_, scan_data, _ = parse_vlbi_cat(cat_dir+vlbi_cat_file)
# Identify valid scans (i.e. exclude phase-up calibration scans)
valid_scans = [scan_name for scan_name in scan_data.keys() if scan_name.startswith('scan No')]

# Set log time axis and target
# - for now only including times during valid VLBI scans
timestamps_log, scan_target_log = [], []
for scan_name in valid_scans:
    # Select scan
    scan_pars = scan_data[scan_name]
    # Create scan time axis
    scan_start = int(scan_pars['start_ts'])
    scan_stop = scan_start + int(scan_pars['duration'])
    scan_time_range = range(scan_start, scan_stop+log_interval, log_interval)
    timestamps_log += scan_time_range
    # Set corresponding target
    scan_target_log += [scan_pars['target']]*len(scan_time_range)
timestamps_log = np.sort(timestamps_log)
n_ts = len(timestamps_log)

# %%
# Load data for all required sensors and interpolate onto log time axis.

if not portal_offline:
    
    # Set sensor names to load
    sensor_names = []
    # Antenna activity (valid value: 'track')
    for ant in ant_names:
        # Antenna status sensors for uvflg file
        sensor_names.append("{}_activity".format(ant))
        sensor_names.append("{}_target".format(ant))
        # Sensors for log file
        #sensor_names.append("tfrmon_tfr_ktt_gnss".format(ant))
        #sensor_names.append("tfrmon_tfr_ktt_gnss_15min".format(ant))
        sensor_names.append("tfrmon_tfr_ktt_utcza".format(ant))
        #sensor_names.append("tfrmon_tfr_ktt_utcza_15min".format(ant))
    
    # Get sensor values
    sensor_data = {}
    for sensor_name in sensor_names:
        # Read sensor values
        timestamps, values = get_sensor(sensor_name, obs_start_time, obs_end_time)
        # Interpolate sensor values onto log time axis
        arg_interp = [np.argmin(np.abs(ts_log-timestamps)) for ts_log in timestamps_log]
        sensor_data[sensor_name] = values[arg_interp]

    # Plot selected sensor data for inspection 
    plt.figure(figsize=(8,4))
    #plt.plot(timestamps_log-timestamps_log[0], sensor_data['tfrmon_tfr_ktt_gnss'])
    #plt.plot(timestamps_log-timestamps_log[0], sensor_data['tfrmon_tfr_ktt_gnss_15min'])
    plt.plot(timestamps_log-timestamps_log[0], sensor_data['tfrmon_tfr_ktt_utcza'], label='tfrmon_tfr_ktt_utcza')
    #plt.plot(timestamps_log-timestamps_log[0], sensor_data['tfrmon_tfr_ktt_utcza_15min'])
    plt.grid(); plt.legend()
    plt.xlabel('Time since start [sec]')
    plt.ylabel('Sensor value')
    
    plt.show()

# %%
# Generate uvflg file    

if portal_offline:

    data_valid = np.zeros(n_ts).astype('bool')

else:

    # Evaluate sensor validity conditions: activity 
    ant_activity_valid = np.zeros((n_ants, n_ts))
    for ii_a, ant in enumerate(ant_names):
        values = sensor_data["{}_activity".format(ant)]
        ant_activity_valid[ii_a,:] = np.array(values)=='track'
    activity_valid = np.sum(ant_activity_valid, axis=0)>=n_ants*quorum
    
    # Evaluate sensor validity conditions: target 
    ant_target_valid = np.zeros((n_ants, n_ts))
    for ii_a, ant in enumerate(ant_names):
        values = sensor_data["{}_target".format(ant)]
        values = [katpoint.Target(tgt_str).name for tgt_str in values]
        ant_target_valid[ii_a,:] = np.array(values)==np.array(scan_target_log)
    target_valid = np.sum(ant_target_valid, axis=0)>=n_ants*quorum
    
    # Combine conditions
    data_valid = np.logical_and(activity_valid,
                                target_valid)

# Plot overview of validity condition over time
fig, axs = plt.subplots(2,1, figsize=(10,5), sharex=True)
axs[0].plot(timestamps_log-timestamps_log[0], data_valid , '.-')
axs[1].plot(timestamps_log-timestamps_log[0], np.sum(ant_activity_valid, axis=0) , '.-', label='activity')
axs[1].plot(timestamps_log-timestamps_log[0], np.sum(ant_target_valid, axis=0) , '.-', label='target')
axs[0].set_title("{} validity over valid scans ({} ants)".format(exp_name, n_ants))
axs[1].set_xlabel('Seconds from start')
axs[0].set_ylabel('Data Valid')
axs[1].set_ylabel('Valid Count')
axs[1].legend()
axs[0].grid(); axs[1].grid()
#axs[1].set_xlim([0,1000])

# Initialise file object
uvflg_file = text_file_man()

# Add header lines
date_today = datetime.now().strftime("%Y-%m-%d")
uvflg_file.add_line('! The following is flagging information for {} in experiment {},'.format(station_code.upper(), exp_name))
uvflg_file.add_line('! extracted on {}.'.format(date_today))
uvflg_file.add_line("opcode='FLAG'")
uvflg_file.add_line('dtimrang = {}   timeoff=0'.format(log_interval))

# Generate flagged time range lines 
ts_flagged_list = get_flagged_ranges(timestamps_log, data_valid)
# Convert timestamp to desired format and write line
if ts_flagged_list != None:
    for ts_beg, ts_end in ts_flagged_list:
        t_beg_ap = ap_time(ts_beg, format='unix')
        t_end_ap = ap_time(ts_end, format='unix')
        t_beg_yday = [tpar.split('.')[0] for tpar in t_beg_ap.to_value('yday').split(':')]
        t_end_yday = [tpar.split('.')[0] for tpar in t_end_ap.to_value('yday').split(':')]
        fl_line = "ant_name='{}' ".format(station_code.upper())
        fl_line += "timerang={},{},{},{}, {},{},{},{} ".format(*t_beg_yday[1:], *t_end_yday[1:])
        fl_line += "reason='Antenna off source' /"
        uvflg_file.add_line(fl_line)

# Print lines for inspection
uvflg_file.print_all()

# Write to file
fn_uvflg = log_dir+exp_name+station_code+'.uvflg'
uvflg_file.write_to_file(fn_uvflg)

plt.show()
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# ! The following is flagging information for ME in experiment es116a,
# ! extracted on 2025-06-06.
# opcode='FLAG'
# dtimrang = 1   timeoff=0
# ant_name='ME' timerang=061,19,34,27, 061,19,34,43 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,37,57, 061,19,38,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,41,57, 061,19,42,13 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,45,28, 061,19,45,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,47,27, 061,19,47,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,50,58, 061,19,51,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,54,57, 061,19,55,13 reason='Antenna off source' /
# ant_name='ME' timerang=061,19,58,28, 061,19,58,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,00,28, 061,20,00,43 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,03,58, 061,20,04,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,07,57, 061,20,08,13 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,11,27, 061,20,11,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,13,28, 061,20,13,43 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,16,58, 061,20,17,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,20,57, 061,20,21,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,24,28, 061,20,24,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,26,28, 061,20,26,43 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,29,57, 061,20,30,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,33,57, 061,20,34,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,37,27, 061,20,37,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,39,27, 061,20,39,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,42,58, 061,20,43,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,46,57, 061,20,47,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,50,28, 061,20,50,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,52,27, 061,20,52,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,55,58, 061,20,56,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,20,59,58, 061,21,00,13 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,03,27, 061,21,03,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,05,28, 061,21,05,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,08,57, 061,21,09,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,12,58, 061,21,13,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,21,27, 061,21,21,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,25,28, 061,21,25,43 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,28,58, 061,21,29,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,30,57, 061,21,31,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,34,27, 061,21,34,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,38,30, 061,21,38,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,41,58, 061,21,42,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,43,58, 061,21,44,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,47,27, 061,21,47,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,51,28, 061,21,51,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,54,58, 061,21,55,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,21,56,57, 061,21,57,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,00,27, 061,22,00,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,02,27, 061,22,02,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,05,58, 061,22,06,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,07,58, 061,22,08,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,11,27, 061,22,11,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,15,27, 061,22,15,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,18,57, 061,22,19,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,20,58, 061,22,21,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,24,27, 061,22,24,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,28,27, 061,22,28,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,31,57, 061,22,32,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,33,57, 061,22,34,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,37,28, 061,22,37,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,41,28, 061,22,41,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,44,58, 061,22,45,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,46,57, 061,22,47,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,50,27, 061,22,50,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,54,27, 061,22,54,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,57,57, 061,22,58,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,22,59,58, 061,23,00,13 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,03,28, 061,23,03,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,07,27, 061,23,07,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,10,58, 061,23,11,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,12,57, 061,23,13,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,16,27, 061,23,16,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,20,27, 061,23,20,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,23,58, 061,23,24,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,25,58, 061,23,26,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,29,28, 061,23,29,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,33,27, 061,23,33,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,36,57, 061,23,37,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,38,57, 061,23,39,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,42,27, 061,23,42,30 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,46,27, 061,23,46,42 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,49,57, 061,23,50,00 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,51,58, 061,23,52,12 reason='Antenna off source' /
# ant_name='ME' timerang=061,23,55,27, 061,23,55,30 reason='Antenna off source' /

# %%
# Create log file

# Intialise log file
obs_log = log_manager()

# Create log file object from obs script log
script_log = log_manager()
for line in d.obs_script_log:
    # Create datetime object for entry
    time_str = line.split('Z')[0].strip()
    line_time = datetime.strptime(time_str, '%Y-%m-%d %H:%M:%S.%f')
    line_time = line_time.replace(tzinfo=timezone.utc)
    # Create keyword
    line_data = [val for val in line.split(' ') if len(val)>0][2:]
    line_key = line_data[0]
    # Create line string
    entry = {'time':line_time,
             'key':line_key,
             'line':' '.join(line_data[1:])}
    script_log.add_entry(entry)

# Add header 
h_entry = {'time': script_log.get_logtime(0),
           'key': 'INFO',
           'line': 'MeerKAT observation log for experiment {} '.format(exp_name)}
obs_log.add_entry(h_entry)

# Load lines from MeerKAT obs script log.
if log_script:

    # Add setup lines
    keep_lines = False
    for log_entry in script_log.log:
        if log_entry['line'].startswith('User product'):
            keep_lines=True
        if log_entry['line'].strip()=='INIT':
            keep_lines=False
        if keep_lines:
            obs_log.add_entry(log_entry)
    
    # Add observation execution lines
    keep_lines = False
    for log_entry in script_log.log:
        if log_entry['line'].strip()=='INIT':
            keep_lines=True
        if keep_lines:
            obs_log.add_entry(log_entry)
        if log_entry['line'].strip()=='DONE':
            keep_lines=False

# Add sensors to the log on the log time axis.
if log_sensors:
    # Timestamps for sensor reporting
    timestamps_sens = np.arange(timestamps_log[0], timestamps_log[-1], sensor_interval)
    ii_ts_sens = [np.argmin(np.abs(ts-timestamps_log)) for ts in timestamps_sens]
    # Add value per sensor timestamp
    for ii_ts in ii_ts_sens:
        # Create entry 
        if portal_offline:
            val_sens = 'UNAVAILABLE'
        else:
            val_sens = sensor_data['tfrmon_tfr_ktt_utcza'][ii_ts]
        ts_sens = timestamps_log[ii_ts]
        dt_sensor = datetime.fromtimestamp(ts_sens)
        dt_sensor.replace(tzinfo=timezone.utc)
        s_entry = {'time': dt_sensor,
                   'key': 'INFO',
                   'line': 'Maser GPS offset [ns]: {} '.format(val_sens)}
        obs_log.add_entry(s_entry)

# Sort entries
obs_log.sort_entries()
# Print for inspection
obs_log.print_log()
# Write to file
fn_log = log_dir+exp_name+station_code+'.log'
obs_log.write_to_file(fn_log)
# Out:
# 2025-03-02 19:24:14.587 INFO MeerKAT observation log for experiment es116a
# 2025-03-02 19:24:14.591 INFO User product = c856M4k_n107M_vlbi
# 2025-03-02 19:24:14.591 INFO Antennas used = m047 m018 m009 m008 m043 m042 m041 m040 m003 m002 m001 m000 m061 m060 m049 m048 m006 m017 m036 m037 m034 m035 m030 m031 m038 m054 m055 m056 m057 m010 m011 m012 m013 m014 m059 m016 m015 m005 m007 m004 m062 m063 m021 m020 m023 m022 m025 m024 m027 m026 m019 m058
# 2025-03-02 19:24:14.628 INFO SETUP
# 2025-03-02 19:24:14.628 INFO Observer = MarcelGouws
# 2025-03-02 19:24:14.628 INFO Description = 'SE-ENG VLBI Observation ES116A'
# 2025-03-02 19:24:14.629 INFO Experiment ID = 20250302-0004
# 2025-03-02 19:24:14.629 INFO Proposal ID = ENG-20240923-MG-01
# 2025-03-02 19:24:14.629 INFO RF centre frequency = 1284 MHz, dump rate = 0.125 Hz
# 2025-03-02 19:24:14.629 INFO Horizon = 20 degrees
# 2025-03-02 19:24:14.629 INFO Quorum = 90% -> 47 of 52 receptor(s), i.e. 5 straggler(s) tolerated
# 2025-03-02 19:24:14.645 INFO Delay tracking = on
# 2025-03-02 19:24:14.645 INFO Switching off all noise diodes
# 2025-03-02 19:24:14.766 INFO Noise diode will not fire automatically while performing canned commands
# 2025-03-02 19:24:14.778 INFO Stopping / readying antennas
# 2025-03-02 19:24:25.580 INFO Capture block ID for SDP product 'array_1_wide_0' ('wide' instrument) = 1740943455
# 2025-03-02 19:24:25.581 INFO Capture block ID for SDP product 'array_1_narrow1_0' ('narrow1' instrument) = 1740943459
# 2025-03-02 19:24:25.633 INFO INIT
# 2025-03-02 19:24:26.299 INFO --------------------------
# 2025-03-02 19:24:26.323 INFO New compound scan: 'scan cal00'
# 2025-03-02 19:24:26.324 INFO Initiating 0-second track on target 'J0408-6545'
# 2025-03-02 19:24:28.086 INFO slewing to target
# 2025-03-02 19:24:42.327 INFO target reached
# 2025-03-02 19:24:42.333 INFO tracking target
# 2025-03-02 19:24:42.335 INFO target tracked for 0 seconds
# 2025-03-02 19:24:42.337 INFO Observing scan: scan cal00
# 2025-03-02 19:24:42.338 INFO Initiating 317.663-second track on target 'J0408-6545'
# 2025-03-02 19:24:43.970 INFO tracking target
# 2025-03-02 19:30:01.725 INFO target tracked for 317.662595034 seconds
# 2025-03-02 19:30:01.744 INFO New compound scan: 'scan No0035'
# 2025-03-02 19:30:01.746 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 19:30:04.086 INFO slewing to target
# 2025-03-02 19:31:35.031 INFO target reached
# 2025-03-02 19:31:35.050 INFO tracking target
# 2025-03-02 19:31:35.060 INFO target tracked for 0 seconds
# 2025-03-02 19:31:35.067 INFO Observing scan: scan No0035
# 2025-03-02 19:31:35.077 INFO Initiating 174.933-second track on target '1013+2449'
# 2025-03-02 19:31:36.552 INFO tracking target
# 2025-03-02 19:33:00.000 INFO Maser GPS offset [ns]: -193.276
# 2025-03-02 19:34:00.000 INFO Maser GPS offset [ns]: -193.272
# 2025-03-02 19:34:31.585 INFO target tracked for 174.93286109 seconds
# 2025-03-02 19:34:31.609 INFO New compound scan: 'scan No0036'
# 2025-03-02 19:34:31.610 INFO Initiating 0-second track on target 'G2'
# 2025-03-02 19:34:34.146 INFO slewing to target
# 2025-03-02 19:34:44.098 INFO target reached
# 2025-03-02 19:34:44.104 INFO tracking target
# 2025-03-02 19:34:44.105 INFO target tracked for 0 seconds
# 2025-03-02 19:34:44.106 INFO Observing scan: scan No0036
# 2025-03-02 19:34:44.107 INFO Initiating 195.894-second track on target 'G2'
# 2025-03-02 19:34:45.461 INFO tracking target
# 2025-03-02 19:35:00.000 INFO Maser GPS offset [ns]: -193.268
# 2025-03-02 19:36:00.000 INFO Maser GPS offset [ns]: -193.265
# 2025-03-02 19:37:00.000 INFO Maser GPS offset [ns]: -193.261
# 2025-03-02 19:38:00.000 INFO Maser GPS offset [ns]: -193.257
# 2025-03-02 19:38:00.000 INFO Maser GPS offset [ns]: -193.257
# 2025-03-02 19:38:01.453 INFO target tracked for 195.893615961 seconds
# 2025-03-02 19:38:01.472 INFO New compound scan: 'scan No0037'
# 2025-03-02 19:38:01.473 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 19:38:03.824 INFO slewing to target
# 2025-03-02 19:38:13.734 INFO target reached
# 2025-03-02 19:38:13.740 INFO tracking target
# 2025-03-02 19:38:13.741 INFO target tracked for 0 seconds
# 2025-03-02 19:38:13.742 INFO Observing scan: scan No0037
# 2025-03-02 19:38:13.743 INFO Initiating 226.257-second track on target '1013+2449'
# 2025-03-02 19:38:15.085 INFO tracking target
# 2025-03-02 19:40:30.000 INFO Maser GPS offset [ns]: -193.248
# 2025-03-02 19:41:00.000 INFO Maser GPS offset [ns]: -193.246
# 2025-03-02 19:42:00.000 INFO Maser GPS offset [ns]: -193.242
# 2025-03-02 19:42:01.438 INFO target tracked for 226.257477045 seconds
# 2025-03-02 19:42:01.461 INFO New compound scan: 'scan No0038'
# 2025-03-02 19:42:01.463 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 19:42:03.733 INFO slewing to target
# 2025-03-02 19:42:13.650 INFO target reached
# 2025-03-02 19:42:13.656 INFO tracking target
# 2025-03-02 19:42:13.657 INFO target tracked for 0 seconds
# 2025-03-02 19:42:13.658 INFO Observing scan: scan No0038
# 2025-03-02 19:42:13.659 INFO Initiating 196.342-second track on target 'J1029A'
# 2025-03-02 19:42:15.074 INFO tracking target
# 2025-03-02 19:43:00.000 INFO Maser GPS offset [ns]: -193.238
# 2025-03-02 19:44:00.000 INFO Maser GPS offset [ns]: -193.234
# 2025-03-02 19:45:00.000 INFO Maser GPS offset [ns]: -193.231
# 2025-03-02 19:45:31.517 INFO target tracked for 196.341737032 seconds
# 2025-03-02 19:45:31.535 INFO New compound scan: 'scan No0039'
# 2025-03-02 19:45:31.537 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 19:45:33.911 INFO slewing to target
# 2025-03-02 19:45:43.789 INFO target reached
# 2025-03-02 19:45:43.795 INFO tracking target
# 2025-03-02 19:45:43.796 INFO target tracked for 0 seconds
# 2025-03-02 19:45:43.797 INFO Observing scan: scan No0039
# 2025-03-02 19:45:43.798 INFO Initiating 106.203-second track on target '1013+2449'
# 2025-03-02 19:45:45.089 INFO tracking target
# 2025-03-02 19:46:00.000 INFO Maser GPS offset [ns]: -193.189
# 2025-03-02 19:47:00.000 INFO Maser GPS offset [ns]: -193.186
# 2025-03-02 19:47:31.368 INFO target tracked for 106.202727079 seconds
# 2025-03-02 19:47:31.390 INFO New compound scan: 'scan No0040'
# 2025-03-02 19:47:31.391 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 19:47:33.746 INFO slewing to target
# 2025-03-02 19:47:43.575 INFO target reached
# 2025-03-02 19:47:43.581 INFO tracking target
# 2025-03-02 19:47:43.582 INFO target tracked for 0 seconds
# 2025-03-02 19:47:43.583 INFO Observing scan: scan No0040
# 2025-03-02 19:47:43.584 INFO Initiating 196.417-second track on target 'J1029A'
# 2025-03-02 19:47:45.048 INFO tracking target
# 2025-03-02 19:48:00.000 INFO Maser GPS offset [ns]: -193.182
# 2025-03-02 19:49:00.000 INFO Maser GPS offset [ns]: -193.178
# 2025-03-02 19:50:00.000 INFO Maser GPS offset [ns]: -193.174
# 2025-03-02 19:51:00.000 INFO Maser GPS offset [ns]: -193.17
# 2025-03-02 19:51:00.000 INFO Maser GPS offset [ns]: -193.17
# 2025-03-02 19:51:01.537 INFO target tracked for 196.416840076 seconds
# 2025-03-02 19:51:01.555 INFO New compound scan: 'scan No0041'
# 2025-03-02 19:51:01.556 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 19:51:04.008 INFO slewing to target
# 2025-03-02 19:51:13.869 INFO target reached
# 2025-03-02 19:51:13.875 INFO tracking target
# 2025-03-02 19:51:13.876 INFO target tracked for 0 seconds
# 2025-03-02 19:51:13.877 INFO Observing scan: scan No0041
# 2025-03-02 19:51:13.878 INFO Initiating 226.123-second track on target '1013+2449'
# 2025-03-02 19:51:15.217 INFO tracking target
# 2025-03-02 19:53:30.000 INFO Maser GPS offset [ns]: -193.161
# 2025-03-02 19:54:00.000 INFO Maser GPS offset [ns]: -193.159
# 2025-03-02 19:55:00.000 INFO Maser GPS offset [ns]: -193.155
# 2025-03-02 19:55:01.441 INFO target tracked for 226.122792006 seconds
# 2025-03-02 19:55:01.465 INFO New compound scan: 'scan No0042'
# 2025-03-02 19:55:01.466 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 19:55:03.843 INFO slewing to target
# 2025-03-02 19:55:13.722 INFO target reached
# 2025-03-02 19:55:13.728 INFO tracking target
# 2025-03-02 19:55:13.729 INFO target tracked for 0 seconds
# 2025-03-02 19:55:13.730 INFO Observing scan: scan No0042
# 2025-03-02 19:55:13.731 INFO Initiating 196.27-second track on target 'J1029B'
# 2025-03-02 19:55:15.398 INFO tracking target
# 2025-03-02 19:56:00.000 INFO Maser GPS offset [ns]: -193.151
# 2025-03-02 19:57:00.000 INFO Maser GPS offset [ns]: -193.147
# 2025-03-02 19:58:00.000 INFO Maser GPS offset [ns]: -193.144
# 2025-03-02 19:58:31.717 INFO target tracked for 196.269579887 seconds
# 2025-03-02 19:58:31.735 INFO New compound scan: 'scan No0043'
# 2025-03-02 19:58:31.737 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 19:58:34.127 INFO slewing to target
# 2025-03-02 19:58:44.038 INFO target reached
# 2025-03-02 19:58:44.044 INFO tracking target
# 2025-03-02 19:58:44.045 INFO target tracked for 0 seconds
# 2025-03-02 19:58:44.046 INFO Observing scan: scan No0043
# 2025-03-02 19:58:44.047 INFO Initiating 105.953-second track on target '1013+2449'
# 2025-03-02 19:58:45.722 INFO tracking target
# 2025-03-02 19:59:00.000 INFO Maser GPS offset [ns]: -193.14
# 2025-03-02 20:00:00.000 INFO Maser GPS offset [ns]: -193.136
# 2025-03-02 20:00:31.775 INFO target tracked for 105.953475952 seconds
# 2025-03-02 20:00:31.799 INFO New compound scan: 'scan No0044'
# 2025-03-02 20:00:31.799 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 20:00:34.144 INFO slewing to target
# 2025-03-02 20:00:43.901 INFO target reached
# 2025-03-02 20:00:43.907 INFO tracking target
# 2025-03-02 20:00:43.908 INFO target tracked for 0 seconds
# 2025-03-02 20:00:43.909 INFO Observing scan: scan No0044
# 2025-03-02 20:00:43.910 INFO Initiating 196.091-second track on target 'J1029B'
# 2025-03-02 20:00:45.587 INFO tracking target
# 2025-03-02 20:01:00.000 INFO Maser GPS offset [ns]: -193.097
# 2025-03-02 20:02:00.000 INFO Maser GPS offset [ns]: -193.093
# 2025-03-02 20:03:00.000 INFO Maser GPS offset [ns]: -193.089
# 2025-03-02 20:04:00.000 INFO Maser GPS offset [ns]: -193.085
# 2025-03-02 20:04:00.000 INFO Maser GPS offset [ns]: -193.085
# 2025-03-02 20:04:01.777 INFO target tracked for 196.0905931 seconds
# 2025-03-02 20:04:01.850 INFO New compound scan: 'scan No0045'
# 2025-03-02 20:04:01.854 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:04:04.091 INFO slewing to target
# 2025-03-02 20:04:13.852 INFO target reached
# 2025-03-02 20:04:13.858 INFO tracking target
# 2025-03-02 20:04:13.859 INFO target tracked for 0 seconds
# 2025-03-02 20:04:13.860 INFO Observing scan: scan No0045
# 2025-03-02 20:04:13.862 INFO Initiating 226.139-second track on target '1013+2449'
# 2025-03-02 20:04:15.175 INFO tracking target
# 2025-03-02 20:06:30.000 INFO Maser GPS offset [ns]: -193.075
# 2025-03-02 20:07:00.000 INFO Maser GPS offset [ns]: -193.073
# 2025-03-02 20:08:00.000 INFO Maser GPS offset [ns]: -193.069
# 2025-03-02 20:08:01.391 INFO target tracked for 226.139148951 seconds
# 2025-03-02 20:08:01.414 INFO New compound scan: 'scan No0046'
# 2025-03-02 20:08:01.415 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 20:08:03.825 INFO slewing to target
# 2025-03-02 20:08:13.604 INFO target reached
# 2025-03-02 20:08:13.609 INFO tracking target
# 2025-03-02 20:08:13.610 INFO target tracked for 0 seconds
# 2025-03-02 20:08:13.611 INFO Observing scan: scan No0046
# 2025-03-02 20:08:13.612 INFO Initiating 196.388-second track on target 'J1029A'
# 2025-03-02 20:08:14.885 INFO tracking target
# 2025-03-02 20:09:00.000 INFO Maser GPS offset [ns]: -193.065
# 2025-03-02 20:10:00.000 INFO Maser GPS offset [ns]: -193.062
# 2025-03-02 20:11:00.000 INFO Maser GPS offset [ns]: -193.058
# 2025-03-02 20:11:31.373 INFO target tracked for 196.3882761 seconds
# 2025-03-02 20:11:31.392 INFO New compound scan: 'scan No0047'
# 2025-03-02 20:11:31.392 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:11:33.873 INFO slewing to target
# 2025-03-02 20:11:43.553 INFO target reached
# 2025-03-02 20:11:43.559 INFO tracking target
# 2025-03-02 20:11:43.561 INFO target tracked for 0 seconds
# 2025-03-02 20:11:43.562 INFO Observing scan: scan No0047
# 2025-03-02 20:11:43.562 INFO Initiating 106.438-second track on target '1013+2449'
# 2025-03-02 20:11:44.969 INFO tracking target
# 2025-03-02 20:12:00.000 INFO Maser GPS offset [ns]: -193.054
# 2025-03-02 20:13:00.000 INFO Maser GPS offset [ns]: -193.05
# 2025-03-02 20:13:31.509 INFO target tracked for 106.437982082 seconds
# 2025-03-02 20:13:31.533 INFO New compound scan: 'scan No0048'
# 2025-03-02 20:13:31.534 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 20:13:33.908 INFO slewing to target
# 2025-03-02 20:13:43.621 INFO target reached
# 2025-03-02 20:13:43.626 INFO tracking target
# 2025-03-02 20:13:43.627 INFO target tracked for 0 seconds
# 2025-03-02 20:13:43.628 INFO Observing scan: scan No0048
# 2025-03-02 20:13:43.630 INFO Initiating 196.371-second track on target 'J1029A'
# 2025-03-02 20:13:45.009 INFO tracking target
# 2025-03-02 20:14:00.000 INFO Maser GPS offset [ns]: -193.046
# 2025-03-02 20:15:00.000 INFO Maser GPS offset [ns]: -193.042
# 2025-03-02 20:16:00.000 INFO Maser GPS offset [ns]: -193.005
# 2025-03-02 20:17:00.000 INFO Maser GPS offset [ns]: -193.001
# 2025-03-02 20:17:00.000 INFO Maser GPS offset [ns]: -193.001
# 2025-03-02 20:17:01.481 INFO target tracked for 196.371110916 seconds
# 2025-03-02 20:17:01.510 INFO New compound scan: 'scan No0049'
# 2025-03-02 20:17:01.511 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:17:03.907 INFO slewing to target
# 2025-03-02 20:17:13.569 INFO target reached
# 2025-03-02 20:17:13.575 INFO tracking target
# 2025-03-02 20:17:13.576 INFO target tracked for 0 seconds
# 2025-03-02 20:17:13.577 INFO Observing scan: scan No0049
# 2025-03-02 20:17:13.578 INFO Initiating 226.423-second track on target '1013+2449'
# 2025-03-02 20:17:14.857 INFO tracking target
# 2025-03-02 20:19:30.000 INFO Maser GPS offset [ns]: -192.991
# 2025-03-02 20:20:00.000 INFO Maser GPS offset [ns]: -192.989
# 2025-03-02 20:21:00.000 INFO Maser GPS offset [ns]: -192.985
# 2025-03-02 20:21:01.377 INFO target tracked for 226.422795057 seconds
# 2025-03-02 20:21:01.402 INFO New compound scan: 'scan No0050'
# 2025-03-02 20:21:01.403 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 20:21:03.812 INFO slewing to target
# 2025-03-02 20:21:13.428 INFO target reached
# 2025-03-02 20:21:13.434 INFO tracking target
# 2025-03-02 20:21:13.435 INFO target tracked for 0 seconds
# 2025-03-02 20:21:13.436 INFO Observing scan: scan No0050
# 2025-03-02 20:21:13.437 INFO Initiating 196.564-second track on target 'J1029A'
# 2025-03-02 20:21:14.860 INFO tracking target
# 2025-03-02 20:22:00.000 INFO Maser GPS offset [ns]: -192.981
# 2025-03-02 20:23:00.000 INFO Maser GPS offset [ns]: -192.977
# 2025-03-02 20:24:00.000 INFO Maser GPS offset [ns]: -192.973
# 2025-03-02 20:24:31.525 INFO target tracked for 196.563637972 seconds
# 2025-03-02 20:24:31.545 INFO New compound scan: 'scan No0051'
# 2025-03-02 20:24:31.546 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:24:33.921 INFO slewing to target
# 2025-03-02 20:24:43.527 INFO target reached
# 2025-03-02 20:24:43.532 INFO tracking target
# 2025-03-02 20:24:43.533 INFO target tracked for 0 seconds
# 2025-03-02 20:24:43.534 INFO Observing scan: scan No0051
# 2025-03-02 20:24:43.535 INFO Initiating 106.465-second track on target '1013+2449'
# 2025-03-02 20:24:45.066 INFO tracking target
# 2025-03-02 20:25:00.000 INFO Maser GPS offset [ns]: -192.969
# 2025-03-02 20:26:00.000 INFO Maser GPS offset [ns]: -192.965
# 2025-03-02 20:26:31.633 INFO target tracked for 106.465289116 seconds
# 2025-03-02 20:26:31.657 INFO New compound scan: 'scan No0052'
# 2025-03-02 20:26:31.659 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 20:26:34.064 INFO slewing to target
# 2025-03-02 20:26:43.577 INFO target reached
# 2025-03-02 20:26:43.582 INFO tracking target
# 2025-03-02 20:26:43.584 INFO target tracked for 0 seconds
# 2025-03-02 20:26:43.585 INFO Observing scan: scan No0052
# 2025-03-02 20:26:43.586 INFO Initiating 196.415-second track on target 'J1029A'
# 2025-03-02 20:26:44.942 INFO tracking target
# 2025-03-02 20:27:00.000 INFO Maser GPS offset [ns]: -192.961
# 2025-03-02 20:28:00.000 INFO Maser GPS offset [ns]: -192.957
# 2025-03-02 20:29:00.000 INFO Maser GPS offset [ns]: -192.953
# 2025-03-02 20:30:00.000 INFO Maser GPS offset [ns]: -192.949
# 2025-03-02 20:30:00.000 INFO Maser GPS offset [ns]: -192.949
# 2025-03-02 20:30:01.457 INFO target tracked for 196.414804935 seconds
# 2025-03-02 20:30:01.478 INFO New compound scan: 'scan No0053'
# 2025-03-02 20:30:01.480 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:30:04.245 INFO slewing to target
# 2025-03-02 20:30:13.754 INFO target reached
# 2025-03-02 20:30:13.760 INFO tracking target
# 2025-03-02 20:30:13.761 INFO target tracked for 0 seconds
# 2025-03-02 20:30:13.762 INFO Observing scan: scan No0053
# 2025-03-02 20:30:13.763 INFO Initiating 226.237-second track on target '1013+2449'
# 2025-03-02 20:30:15.086 INFO tracking target
# 2025-03-02 20:32:30.000 INFO Maser GPS offset [ns]: -192.908
# 2025-03-02 20:33:00.000 INFO Maser GPS offset [ns]: -192.906
# 2025-03-02 20:34:00.000 INFO Maser GPS offset [ns]: -192.902
# 2025-03-02 20:34:01.425 INFO target tracked for 226.237323046 seconds
# 2025-03-02 20:34:01.448 INFO New compound scan: 'scan No0054'
# 2025-03-02 20:34:01.450 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 20:34:03.862 INFO slewing to target
# 2025-03-02 20:34:13.370 INFO target reached
# 2025-03-02 20:34:13.375 INFO tracking target
# 2025-03-02 20:34:13.377 INFO target tracked for 0 seconds
# 2025-03-02 20:34:13.378 INFO Observing scan: scan No0054
# 2025-03-02 20:34:13.379 INFO Initiating 196.622-second track on target 'J1029B'
# 2025-03-02 20:34:14.639 INFO tracking target
# 2025-03-02 20:35:00.000 INFO Maser GPS offset [ns]: -192.898
# 2025-03-02 20:36:00.000 INFO Maser GPS offset [ns]: -192.894
# 2025-03-02 20:37:00.000 INFO Maser GPS offset [ns]: -192.89
# 2025-03-02 20:37:31.361 INFO target tracked for 196.621697903 seconds
# 2025-03-02 20:37:31.380 INFO New compound scan: 'scan No0055'
# 2025-03-02 20:37:31.381 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:37:33.759 INFO slewing to target
# 2025-03-02 20:37:43.222 INFO target reached
# 2025-03-02 20:37:43.227 INFO tracking target
# 2025-03-02 20:37:43.229 INFO target tracked for 0 seconds
# 2025-03-02 20:37:43.230 INFO Observing scan: scan No0055
# 2025-03-02 20:37:43.231 INFO Initiating 106.77-second track on target '1013+2449'
# 2025-03-02 20:37:44.558 INFO tracking target
# 2025-03-02 20:38:00.000 INFO Maser GPS offset [ns]: -192.886
# 2025-03-02 20:39:00.000 INFO Maser GPS offset [ns]: -192.882
# 2025-03-02 20:39:31.428 INFO target tracked for 106.769937992 seconds
# 2025-03-02 20:39:31.453 INFO New compound scan: 'scan No0056'
# 2025-03-02 20:39:31.454 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 20:39:33.646 INFO slewing to target
# 2025-03-02 20:39:43.055 INFO target reached
# 2025-03-02 20:39:43.060 INFO tracking target
# 2025-03-02 20:39:43.062 INFO target tracked for 0 seconds
# 2025-03-02 20:39:43.063 INFO Observing scan: scan No0056
# 2025-03-02 20:39:43.064 INFO Initiating 196.937-second track on target 'J1029B'
# 2025-03-02 20:39:44.572 INFO tracking target
# 2025-03-02 20:40:00.000 INFO Maser GPS offset [ns]: -192.878
# 2025-03-02 20:41:00.000 INFO Maser GPS offset [ns]: -192.874
# 2025-03-02 20:42:00.000 INFO Maser GPS offset [ns]: -192.87
# 2025-03-02 20:43:00.000 INFO Maser GPS offset [ns]: -192.866
# 2025-03-02 20:43:00.000 INFO Maser GPS offset [ns]: -192.866
# 2025-03-02 20:43:01.589 INFO target tracked for 196.936975002 seconds
# 2025-03-02 20:43:01.608 INFO New compound scan: 'scan No0057'
# 2025-03-02 20:43:01.609 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:43:04.161 INFO slewing to target
# 2025-03-02 20:43:13.571 INFO target reached
# 2025-03-02 20:43:13.577 INFO tracking target
# 2025-03-02 20:43:13.578 INFO target tracked for 0 seconds
# 2025-03-02 20:43:13.579 INFO Observing scan: scan No0057
# 2025-03-02 20:43:13.580 INFO Initiating 226.42-second track on target '1013+2449'
# 2025-03-02 20:43:14.874 INFO tracking target
# 2025-03-02 20:45:30.000 INFO Maser GPS offset [ns]: -192.826
# 2025-03-02 20:46:00.000 INFO Maser GPS offset [ns]: -192.824
# 2025-03-02 20:47:00.000 INFO Maser GPS offset [ns]: -192.82
# 2025-03-02 20:47:01.395 INFO target tracked for 226.420283079 seconds
# 2025-03-02 20:47:01.419 INFO New compound scan: 'scan No0058'
# 2025-03-02 20:47:01.420 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 20:47:04.051 INFO slewing to target
# 2025-03-02 20:47:13.378 INFO target reached
# 2025-03-02 20:47:13.383 INFO tracking target
# 2025-03-02 20:47:13.384 INFO target tracked for 0 seconds
# 2025-03-02 20:47:13.385 INFO Observing scan: scan No0058
# 2025-03-02 20:47:13.386 INFO Initiating 196.614-second track on target 'J1029B'
# 2025-03-02 20:47:14.750 INFO tracking target
# 2025-03-02 20:48:00.000 INFO Maser GPS offset [ns]: -192.816
# 2025-03-02 20:49:00.000 INFO Maser GPS offset [ns]: -192.812
# 2025-03-02 20:50:00.000 INFO Maser GPS offset [ns]: -192.808
# 2025-03-02 20:50:31.461 INFO target tracked for 196.614085913 seconds
# 2025-03-02 20:50:31.482 INFO New compound scan: 'scan No0059'
# 2025-03-02 20:50:31.483 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:50:34.088 INFO slewing to target
# 2025-03-02 20:50:43.411 INFO target reached
# 2025-03-02 20:50:43.417 INFO tracking target
# 2025-03-02 20:50:43.418 INFO target tracked for 0 seconds
# 2025-03-02 20:50:43.419 INFO Observing scan: scan No0059
# 2025-03-02 20:50:43.420 INFO Initiating 106.58-second track on target '1013+2449'
# 2025-03-02 20:50:44.678 INFO tracking target
# 2025-03-02 20:51:00.000 INFO Maser GPS offset [ns]: -192.804
# 2025-03-02 20:52:00.000 INFO Maser GPS offset [ns]: -192.8
# 2025-03-02 20:52:31.357 INFO target tracked for 106.580444098 seconds
# 2025-03-02 20:52:31.380 INFO New compound scan: 'scan No0060'
# 2025-03-02 20:52:31.381 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 20:52:34.079 INFO slewing to target
# 2025-03-02 20:52:43.389 INFO target reached
# 2025-03-02 20:52:43.395 INFO tracking target
# 2025-03-02 20:52:43.396 INFO target tracked for 0 seconds
# 2025-03-02 20:52:43.397 INFO Observing scan: scan No0060
# 2025-03-02 20:52:43.398 INFO Initiating 196.603-second track on target 'J1029B'
# 2025-03-02 20:52:44.778 INFO tracking target
# 2025-03-02 20:53:00.000 INFO Maser GPS offset [ns]: -192.796
# 2025-03-02 20:54:00.000 INFO Maser GPS offset [ns]: -192.792
# 2025-03-02 20:55:00.000 INFO Maser GPS offset [ns]: -192.788
# 2025-03-02 20:56:00.000 INFO Maser GPS offset [ns]: -192.784
# 2025-03-02 20:56:00.000 INFO Maser GPS offset [ns]: -192.784
# 2025-03-02 20:56:01.481 INFO target tracked for 196.60251689 seconds
# 2025-03-02 20:56:01.500 INFO New compound scan: 'scan No0061'
# 2025-03-02 20:56:01.501 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 20:56:04.072 INFO slewing to target
# 2025-03-02 20:56:13.336 INFO target reached
# 2025-03-02 20:56:13.342 INFO tracking target
# 2025-03-02 20:56:13.344 INFO target tracked for 0 seconds
# 2025-03-02 20:56:13.345 INFO Observing scan: scan No0061
# 2025-03-02 20:56:13.345 INFO Initiating 226.655-second track on target '1013+2449'
# 2025-03-02 20:56:14.836 INFO tracking target
# 2025-03-02 20:58:30.000 INFO Maser GPS offset [ns]: -192.773
# 2025-03-02 20:59:00.000 INFO Maser GPS offset [ns]: -192.771
# 2025-03-02 21:00:00.000 INFO Maser GPS offset [ns]: -192.767
# 2025-03-02 21:00:01.591 INFO target tracked for 226.655014038 seconds
# 2025-03-02 21:00:01.617 INFO New compound scan: 'scan No0062'
# 2025-03-02 21:00:01.618 INFO Initiating 0-second track on target 'G2'
# 2025-03-02 21:00:04.676 INFO slewing to target
# 2025-03-02 21:00:13.862 INFO target reached
# 2025-03-02 21:00:13.868 INFO tracking target
# 2025-03-02 21:00:13.869 INFO target tracked for 0 seconds
# 2025-03-02 21:00:13.870 INFO Observing scan: scan No0062
# 2025-03-02 21:00:13.871 INFO Initiating 196.129-second track on target 'G2'
# 2025-03-02 21:00:15.247 INFO tracking target
# 2025-03-02 21:01:00.000 INFO Maser GPS offset [ns]: -192.736
# 2025-03-02 21:02:00.000 INFO Maser GPS offset [ns]: -192.732
# 2025-03-02 21:03:00.000 INFO Maser GPS offset [ns]: -192.728
# 2025-03-02 21:03:31.477 INFO target tracked for 196.129300117 seconds
# 2025-03-02 21:03:31.495 INFO New compound scan: 'scan No0063'
# 2025-03-02 21:03:31.496 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:03:33.842 INFO slewing to target
# 2025-03-02 21:03:42.952 INFO target reached
# 2025-03-02 21:03:42.958 INFO tracking target
# 2025-03-02 21:03:42.959 INFO target tracked for 0 seconds
# 2025-03-02 21:03:42.960 INFO Observing scan: scan No0063
# 2025-03-02 21:03:42.961 INFO Initiating 107.04-second track on target '1013+2449'
# 2025-03-02 21:03:44.357 INFO tracking target
# 2025-03-02 21:04:00.000 INFO Maser GPS offset [ns]: -192.723
# 2025-03-02 21:05:00.000 INFO Maser GPS offset [ns]: -192.719
# 2025-03-02 21:05:31.497 INFO target tracked for 107.039580107 seconds
# 2025-03-02 21:05:31.521 INFO New compound scan: 'scan No0064'
# 2025-03-02 21:05:31.522 INFO Initiating 0-second track on target 'G2'
# 2025-03-02 21:05:33.914 INFO slewing to target
# 2025-03-02 21:05:43.075 INFO target reached
# 2025-03-02 21:05:43.081 INFO tracking target
# 2025-03-02 21:05:43.082 INFO target tracked for 0 seconds
# 2025-03-02 21:05:43.083 INFO Observing scan: scan No0064
# 2025-03-02 21:05:43.084 INFO Initiating 196.916-second track on target 'G2'
# 2025-03-02 21:05:44.455 INFO tracking target
# 2025-03-02 21:06:00.000 INFO Maser GPS offset [ns]: -192.715
# 2025-03-02 21:07:00.000 INFO Maser GPS offset [ns]: -192.711
# 2025-03-02 21:08:00.000 INFO Maser GPS offset [ns]: -192.707
# 2025-03-02 21:09:00.000 INFO Maser GPS offset [ns]: -192.703
# 2025-03-02 21:09:00.000 INFO Maser GPS offset [ns]: -192.703
# 2025-03-02 21:09:01.469 INFO target tracked for 196.916212082 seconds
# 2025-03-02 21:09:01.486 INFO New compound scan: 'scan No0065'
# 2025-03-02 21:09:01.487 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:09:03.919 INFO slewing to target
# 2025-03-02 21:09:12.981 INFO target reached
# 2025-03-02 21:09:12.987 INFO tracking target
# 2025-03-02 21:09:12.988 INFO target tracked for 0 seconds
# 2025-03-02 21:09:12.989 INFO Observing scan: scan No0065
# 2025-03-02 21:09:12.990 INFO Initiating 227.011-second track on target '1013+2449'
# 2025-03-02 21:09:14.343 INFO tracking target
# 2025-03-02 21:11:30.000 INFO Maser GPS offset [ns]: -192.693
# 2025-03-02 21:12:00.000 INFO Maser GPS offset [ns]: -192.69
# 2025-03-02 21:13:00.000 INFO Maser GPS offset [ns]: -192.686
# 2025-03-02 21:13:00.000 INFO Maser GPS offset [ns]: -192.686
# 2025-03-02 21:13:01.453 INFO target tracked for 227.010925055 seconds
# 2025-03-02 21:13:01.484 INFO New compound scan: 'scan No0066'
# 2025-03-02 21:13:01.485 INFO Initiating 0-second track on target '4C39.25'
# 2025-03-02 21:13:03.925 INFO slewing to target
# 2025-03-02 21:13:23.353 INFO target reached
# 2025-03-02 21:13:23.359 INFO tracking target
# 2025-03-02 21:13:23.360 INFO target tracked for 0 seconds
# 2025-03-02 21:13:23.361 INFO Observing scan: scan No0066
# 2025-03-02 21:13:23.362 INFO Initiating 486.638-second track on target '4C39.25'
# 2025-03-02 21:13:24.798 INFO tracking target
# 2025-03-02 21:15:30.000 INFO Maser GPS offset [ns]: -192.651
# 2025-03-02 21:16:00.000 INFO Maser GPS offset [ns]: -192.649
# 2025-03-02 21:17:00.000 INFO Maser GPS offset [ns]: -192.644
# 2025-03-02 21:18:00.000 INFO Maser GPS offset [ns]: -192.64
# 2025-03-02 21:19:00.000 INFO Maser GPS offset [ns]: -192.636
# 2025-03-02 21:20:00.000 INFO Maser GPS offset [ns]: -192.632
# 2025-03-02 21:21:00.000 INFO Maser GPS offset [ns]: -192.628
# 2025-03-02 21:21:30.000 INFO Maser GPS offset [ns]: -192.626
# 2025-03-02 21:21:31.465 INFO target tracked for 486.638458014 seconds
# 2025-03-02 21:21:31.484 INFO New compound scan: 'scan No0067'
# 2025-03-02 21:21:31.485 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:21:33.802 INFO slewing to target
# 2025-03-02 21:21:53.685 INFO target reached
# 2025-03-02 21:21:53.692 INFO tracking target
# 2025-03-02 21:21:53.693 INFO target tracked for 0 seconds
# 2025-03-02 21:21:53.694 INFO Observing scan: scan No0067
# 2025-03-02 21:21:53.695 INFO Initiating 216.306-second track on target '1013+2449'
# 2025-03-02 21:21:55.029 INFO tracking target
# 2025-03-02 21:24:00.000 INFO Maser GPS offset [ns]: -192.615
# 2025-03-02 21:24:00.000 INFO Maser GPS offset [ns]: -192.615
# 2025-03-02 21:25:00.000 INFO Maser GPS offset [ns]: -192.611
# 2025-03-02 21:25:31.433 INFO target tracked for 216.30576396 seconds
# 2025-03-02 21:25:31.435 INFO NOTE: Phase-up correction not implemented. Continuing.
# 2025-03-02 21:25:31.436 INFO Successful phase-up correction.
# 2025-03-02 21:25:31.437 INFO Resetting re-phase timer to 1740957931.44
# 2025-03-02 21:25:31.459 INFO New compound scan: 'scan No0068'
# 2025-03-02 21:25:31.460 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 21:25:34.575 INFO slewing to target
# 2025-03-02 21:25:43.401 INFO target reached
# 2025-03-02 21:25:43.407 INFO tracking target
# 2025-03-02 21:25:43.408 INFO target tracked for 0 seconds
# 2025-03-02 21:25:43.409 INFO Observing scan: scan No0068
# 2025-03-02 21:25:43.410 INFO Initiating 196.591-second track on target 'J1029A'
# 2025-03-02 21:25:44.821 INFO tracking target
# 2025-03-02 21:26:00.000 INFO Maser GPS offset [ns]: -192.607
# 2025-03-02 21:27:00.000 INFO Maser GPS offset [ns]: -192.603
# 2025-03-02 21:28:00.000 INFO Maser GPS offset [ns]: -192.599
# 2025-03-02 21:29:00.000 INFO Maser GPS offset [ns]: -192.594
# 2025-03-02 21:29:01.509 INFO target tracked for 196.590727091 seconds
# 2025-03-02 21:29:01.528 INFO New compound scan: 'scan No0069'
# 2025-03-02 21:29:01.530 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:29:03.923 INFO slewing to target
# 2025-03-02 21:29:12.685 INFO target reached
# 2025-03-02 21:29:12.690 INFO tracking target
# 2025-03-02 21:29:12.691 INFO target tracked for 0 seconds
# 2025-03-02 21:29:12.692 INFO Observing scan: scan No0069
# 2025-03-02 21:29:12.694 INFO Initiating 107.307-second track on target '1013+2449'
# 2025-03-02 21:29:13.976 INFO tracking target
# 2025-03-02 21:30:00.000 INFO Maser GPS offset [ns]: -192.59
# 2025-03-02 21:31:00.000 INFO Maser GPS offset [ns]: -192.563
# 2025-03-02 21:31:01.384 INFO target tracked for 107.30708909 seconds
# 2025-03-02 21:31:01.409 INFO New compound scan: 'scan No0070'
# 2025-03-02 21:31:01.410 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 21:31:03.880 INFO slewing to target
# 2025-03-02 21:31:12.542 INFO target reached
# 2025-03-02 21:31:12.548 INFO tracking target
# 2025-03-02 21:31:12.550 INFO target tracked for 0 seconds
# 2025-03-02 21:31:12.551 INFO Observing scan: scan No0070
# 2025-03-02 21:31:12.552 INFO Initiating 197.449-second track on target 'J1029A'
# 2025-03-02 21:31:13.813 INFO tracking target
# 2025-03-02 21:32:00.000 INFO Maser GPS offset [ns]: -192.559
# 2025-03-02 21:33:00.000 INFO Maser GPS offset [ns]: -192.555
# 2025-03-02 21:34:00.000 INFO Maser GPS offset [ns]: -192.55
# 2025-03-02 21:34:30.000 INFO Maser GPS offset [ns]: -192.548
# 2025-03-02 21:34:31.363 INFO target tracked for 197.448740959 seconds
# 2025-03-02 21:34:31.383 INFO New compound scan: 'scan No0071'
# 2025-03-02 21:34:31.384 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:34:34.001 INFO slewing to target
# 2025-03-02 21:34:42.675 INFO target reached
# 2025-03-02 21:34:42.681 INFO tracking target
# 2025-03-02 21:34:42.682 INFO target tracked for 0 seconds
# 2025-03-02 21:34:42.683 INFO Observing scan: scan No0071
# 2025-03-02 21:34:42.684 INFO Initiating 227.317-second track on target '1013+2449'
# 2025-03-02 21:34:44.019 INFO tracking target
# 2025-03-02 21:37:00.000 INFO Maser GPS offset [ns]: -192.538
# 2025-03-02 21:37:00.000 INFO Maser GPS offset [ns]: -192.538
# 2025-03-02 21:38:00.000 INFO Maser GPS offset [ns]: -192.534
# 2025-03-02 21:38:31.437 INFO target tracked for 227.316946983 seconds
# 2025-03-02 21:38:31.461 INFO New compound scan: 'scan No0072'
# 2025-03-02 21:38:31.462 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 21:38:34.641 INFO slewing to target
# 2025-03-02 21:38:43.201 INFO target reached
# 2025-03-02 21:38:43.207 INFO tracking target
# 2025-03-02 21:38:43.208 INFO target tracked for 0 seconds
# 2025-03-02 21:38:43.209 INFO Observing scan: scan No0072
# 2025-03-02 21:38:43.210 INFO Initiating 196.79-second track on target 'J1029B'
# 2025-03-02 21:38:44.669 INFO tracking target
# 2025-03-02 21:39:00.000 INFO Maser GPS offset [ns]: -192.529
# 2025-03-02 21:40:00.000 INFO Maser GPS offset [ns]: -192.525
# 2025-03-02 21:41:00.000 INFO Maser GPS offset [ns]: -192.521
# 2025-03-02 21:42:00.000 INFO Maser GPS offset [ns]: -192.517
# 2025-03-02 21:42:01.557 INFO target tracked for 196.790218115 seconds
# 2025-03-02 21:42:01.580 INFO New compound scan: 'scan No0073'
# 2025-03-02 21:42:01.581 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:42:03.949 INFO slewing to target
# 2025-03-02 21:42:12.457 INFO target reached
# 2025-03-02 21:42:12.462 INFO tracking target
# 2025-03-02 21:42:12.463 INFO target tracked for 0 seconds
# 2025-03-02 21:42:12.464 INFO Observing scan: scan No0073
# 2025-03-02 21:42:12.465 INFO Initiating 107.535-second track on target '1013+2449'
# 2025-03-02 21:42:13.868 INFO tracking target
# 2025-03-02 21:43:00.000 INFO Maser GPS offset [ns]: -192.512
# 2025-03-02 21:44:00.000 INFO Maser GPS offset [ns]: -192.508
# 2025-03-02 21:44:01.537 INFO target tracked for 107.535425901 seconds
# 2025-03-02 21:44:01.561 INFO New compound scan: 'scan No0074'
# 2025-03-02 21:44:01.563 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 21:44:03.924 INFO slewing to target
# 2025-03-02 21:44:12.436 INFO target reached
# 2025-03-02 21:44:12.441 INFO tracking target
# 2025-03-02 21:44:12.443 INFO target tracked for 0 seconds
# 2025-03-02 21:44:12.444 INFO Observing scan: scan No0074
# 2025-03-02 21:44:12.445 INFO Initiating 197.556-second track on target 'J1029B'
# 2025-03-02 21:44:13.778 INFO tracking target
# 2025-03-02 21:45:00.000 INFO Maser GPS offset [ns]: -192.504
# 2025-03-02 21:46:00.000 INFO Maser GPS offset [ns]: -192.479
# 2025-03-02 21:47:00.000 INFO Maser GPS offset [ns]: -192.474
# 2025-03-02 21:47:30.000 INFO Maser GPS offset [ns]: -192.472
# 2025-03-02 21:47:31.435 INFO target tracked for 197.555602074 seconds
# 2025-03-02 21:47:31.463 INFO New compound scan: 'scan No0075'
# 2025-03-02 21:47:31.464 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:47:34.038 INFO slewing to target
# 2025-03-02 21:47:42.496 INFO target reached
# 2025-03-02 21:47:42.501 INFO tracking target
# 2025-03-02 21:47:42.502 INFO target tracked for 0 seconds
# 2025-03-02 21:47:42.503 INFO Observing scan: scan No0075
# 2025-03-02 21:47:42.504 INFO Initiating 227.496-second track on target '1013+2449'
# 2025-03-02 21:47:43.868 INFO tracking target
# 2025-03-02 21:50:00.000 INFO Maser GPS offset [ns]: -192.462
# 2025-03-02 21:50:00.000 INFO Maser GPS offset [ns]: -192.462
# 2025-03-02 21:51:00.000 INFO Maser GPS offset [ns]: -192.457
# 2025-03-02 21:51:31.433 INFO target tracked for 227.496304035 seconds
# 2025-03-02 21:51:31.458 INFO New compound scan: 'scan No0076'
# 2025-03-02 21:51:31.460 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 21:51:34.553 INFO slewing to target
# 2025-03-02 21:51:43.063 INFO target reached
# 2025-03-02 21:51:43.068 INFO tracking target
# 2025-03-02 21:51:43.070 INFO target tracked for 0 seconds
# 2025-03-02 21:51:43.070 INFO Observing scan: scan No0076
# 2025-03-02 21:51:43.071 INFO Initiating 196.929-second track on target 'J1029A'
# 2025-03-02 21:51:44.512 INFO tracking target
# 2025-03-02 21:52:00.000 INFO Maser GPS offset [ns]: -192.453
# 2025-03-02 21:53:00.000 INFO Maser GPS offset [ns]: -192.449
# 2025-03-02 21:54:00.000 INFO Maser GPS offset [ns]: -192.444
# 2025-03-02 21:55:00.000 INFO Maser GPS offset [ns]: -192.44
# 2025-03-02 21:55:01.504 INFO target tracked for 196.929054022 seconds
# 2025-03-02 21:55:01.523 INFO New compound scan: 'scan No0077'
# 2025-03-02 21:55:01.524 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 21:55:04.152 INFO slewing to target
# 2025-03-02 21:55:12.678 INFO target reached
# 2025-03-02 21:55:12.684 INFO tracking target
# 2025-03-02 21:55:12.685 INFO target tracked for 0 seconds
# 2025-03-02 21:55:12.686 INFO Observing scan: scan No0077
# 2025-03-02 21:55:12.687 INFO Initiating 107.313-second track on target '1013+2449'
# 2025-03-02 21:55:14.056 INFO tracking target
# 2025-03-02 21:56:00.000 INFO Maser GPS offset [ns]: -192.436
# 2025-03-02 21:57:00.000 INFO Maser GPS offset [ns]: -192.432
# 2025-03-02 21:57:01.465 INFO target tracked for 107.313414097 seconds
# 2025-03-02 21:57:01.491 INFO New compound scan: 'scan No0078'
# 2025-03-02 21:57:01.492 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 21:57:03.759 INFO slewing to target
# 2025-03-02 21:57:12.338 INFO target reached
# 2025-03-02 21:57:12.344 INFO tracking target
# 2025-03-02 21:57:12.345 INFO target tracked for 0 seconds
# 2025-03-02 21:57:12.346 INFO Observing scan: scan No0078
# 2025-03-02 21:57:12.347 INFO Initiating 197.653-second track on target 'J1029A'
# 2025-03-02 21:57:13.670 INFO tracking target
# 2025-03-02 21:58:00.000 INFO Maser GPS offset [ns]: -192.427
# 2025-03-02 21:59:00.000 INFO Maser GPS offset [ns]: -192.423
# 2025-03-02 22:00:00.000 INFO Maser GPS offset [ns]: -192.419
# 2025-03-02 22:00:31.425 INFO target tracked for 197.653223038 seconds
# 2025-03-02 22:00:31.444 INFO New compound scan: 'scan No0079'
# 2025-03-02 22:00:31.445 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:00:33.909 INFO slewing to target
# 2025-03-02 22:00:42.470 INFO target reached
# 2025-03-02 22:00:42.477 INFO tracking target
# 2025-03-02 22:00:42.478 INFO target tracked for 0 seconds
# 2025-03-02 22:00:42.479 INFO Observing scan: scan No0079
# 2025-03-02 22:00:42.480 INFO Initiating 107.52-second track on target '1013+2449'
# 2025-03-02 22:00:43.835 INFO tracking target
# 2025-03-02 22:01:00.000 INFO Maser GPS offset [ns]: -192.396
# 2025-03-02 22:02:00.000 INFO Maser GPS offset [ns]: -192.391
# 2025-03-02 22:02:31.453 INFO target tracked for 107.520283937 seconds
# 2025-03-02 22:02:31.477 INFO New compound scan: 'scan No0080'
# 2025-03-02 22:02:31.478 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 22:02:33.875 INFO slewing to target
# 2025-03-02 22:02:42.454 INFO target reached
# 2025-03-02 22:02:42.459 INFO tracking target
# 2025-03-02 22:02:42.460 INFO target tracked for 0 seconds
# 2025-03-02 22:02:42.461 INFO Observing scan: scan No0080
# 2025-03-02 22:02:42.462 INFO Initiating 197.538-second track on target 'J1029B'
# 2025-03-02 22:02:43.907 INFO tracking target
# 2025-03-02 22:03:00.000 INFO Maser GPS offset [ns]: -192.387
# 2025-03-02 22:04:00.000 INFO Maser GPS offset [ns]: -192.383
# 2025-03-02 22:05:00.000 INFO Maser GPS offset [ns]: -192.378
# 2025-03-02 22:06:00.000 INFO Maser GPS offset [ns]: -192.374
# 2025-03-02 22:06:01.545 INFO target tracked for 197.538408995 seconds
# 2025-03-02 22:06:01.563 INFO New compound scan: 'scan No0081'
# 2025-03-02 22:06:01.564 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:06:04.052 INFO slewing to target
# 2025-03-02 22:06:12.612 INFO target reached
# 2025-03-02 22:06:12.617 INFO tracking target
# 2025-03-02 22:06:12.618 INFO target tracked for 0 seconds
# 2025-03-02 22:06:12.619 INFO Observing scan: scan No0081
# 2025-03-02 22:06:12.620 INFO Initiating 107.38-second track on target '1013+2449'
# 2025-03-02 22:06:14.097 INFO tracking target
# 2025-03-02 22:07:00.000 INFO Maser GPS offset [ns]: -192.37
# 2025-03-02 22:08:00.000 INFO Maser GPS offset [ns]: -192.365
# 2025-03-02 22:08:01.577 INFO target tracked for 107.380054951 seconds
# 2025-03-02 22:08:01.614 INFO New compound scan: 'scan No0082'
# 2025-03-02 22:08:01.615 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 22:08:04.099 INFO slewing to target
# 2025-03-02 22:08:12.809 INFO target reached
# 2025-03-02 22:08:12.814 INFO tracking target
# 2025-03-02 22:08:12.815 INFO target tracked for 0 seconds
# 2025-03-02 22:08:12.816 INFO Observing scan: scan No0082
# 2025-03-02 22:08:12.817 INFO Initiating 197.183-second track on target 'J1029B'
# 2025-03-02 22:08:14.138 INFO tracking target
# 2025-03-02 22:09:00.000 INFO Maser GPS offset [ns]: -192.361
# 2025-03-02 22:10:00.000 INFO Maser GPS offset [ns]: -192.357
# 2025-03-02 22:11:00.000 INFO Maser GPS offset [ns]: -192.353
# 2025-03-02 22:11:30.000 INFO Maser GPS offset [ns]: -192.35
# 2025-03-02 22:11:31.421 INFO target tracked for 197.183420897 seconds
# 2025-03-02 22:11:31.439 INFO New compound scan: 'scan No0083'
# 2025-03-02 22:11:31.440 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:11:33.803 INFO slewing to target
# 2025-03-02 22:11:42.366 INFO target reached
# 2025-03-02 22:11:42.372 INFO tracking target
# 2025-03-02 22:11:42.373 INFO target tracked for 0 seconds
# 2025-03-02 22:11:42.374 INFO Observing scan: scan No0083
# 2025-03-02 22:11:42.375 INFO Initiating 227.626-second track on target '1013+2449'
# 2025-03-02 22:11:43.637 INFO tracking target
# 2025-03-02 22:14:00.000 INFO Maser GPS offset [ns]: -192.34
# 2025-03-02 22:14:00.000 INFO Maser GPS offset [ns]: -192.34
# 2025-03-02 22:15:00.000 INFO Maser GPS offset [ns]: -192.335
# 2025-03-02 22:15:31.349 INFO target tracked for 227.625576973 seconds
# 2025-03-02 22:15:31.373 INFO New compound scan: 'scan No0084'
# 2025-03-02 22:15:31.374 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 22:15:33.704 INFO slewing to target
# 2025-03-02 22:15:42.415 INFO target reached
# 2025-03-02 22:15:42.420 INFO tracking target
# 2025-03-02 22:15:42.421 INFO target tracked for 0 seconds
# 2025-03-02 22:15:42.422 INFO Observing scan: scan No0084
# 2025-03-02 22:15:42.423 INFO Initiating 197.577-second track on target 'J1029A'
# 2025-03-02 22:15:43.767 INFO tracking target
# 2025-03-02 22:16:00.000 INFO Maser GPS offset [ns]: -192.315
# 2025-03-02 22:17:00.000 INFO Maser GPS offset [ns]: -192.31
# 2025-03-02 22:18:00.000 INFO Maser GPS offset [ns]: -192.306
# 2025-03-02 22:19:00.000 INFO Maser GPS offset [ns]: -192.302
# 2025-03-02 22:19:01.422 INFO target tracked for 197.577310085 seconds
# 2025-03-02 22:19:01.441 INFO New compound scan: 'scan No0085'
# 2025-03-02 22:19:01.442 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:19:03.972 INFO slewing to target
# 2025-03-02 22:19:12.633 INFO target reached
# 2025-03-02 22:19:12.638 INFO tracking target
# 2025-03-02 22:19:12.639 INFO target tracked for 0 seconds
# 2025-03-02 22:19:12.640 INFO Observing scan: scan No0085
# 2025-03-02 22:19:12.641 INFO Initiating 107.359-second track on target '1013+2449'
# 2025-03-02 22:19:14.036 INFO tracking target
# 2025-03-02 22:20:00.000 INFO Maser GPS offset [ns]: -192.297
# 2025-03-02 22:21:00.000 INFO Maser GPS offset [ns]: -192.293
# 2025-03-02 22:21:01.493 INFO target tracked for 107.359124899 seconds
# 2025-03-02 22:21:01.516 INFO New compound scan: 'scan No0086'
# 2025-03-02 22:21:01.517 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 22:21:03.920 INFO slewing to target
# 2025-03-02 22:21:12.580 INFO target reached
# 2025-03-02 22:21:12.585 INFO tracking target
# 2025-03-02 22:21:12.586 INFO target tracked for 0 seconds
# 2025-03-02 22:21:12.587 INFO Observing scan: scan No0086
# 2025-03-02 22:21:12.588 INFO Initiating 197.412-second track on target 'J1029A'
# 2025-03-02 22:21:13.835 INFO tracking target
# 2025-03-02 22:22:00.000 INFO Maser GPS offset [ns]: -192.288
# 2025-03-02 22:23:00.000 INFO Maser GPS offset [ns]: -192.284
# 2025-03-02 22:24:00.000 INFO Maser GPS offset [ns]: -192.28
# 2025-03-02 22:24:30.000 INFO Maser GPS offset [ns]: -192.278
# 2025-03-02 22:24:31.345 INFO target tracked for 197.412440062 seconds
# 2025-03-02 22:24:31.366 INFO New compound scan: 'scan No0087'
# 2025-03-02 22:24:31.367 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:24:33.715 INFO slewing to target
# 2025-03-02 22:24:42.376 INFO target reached
# 2025-03-02 22:24:42.381 INFO tracking target
# 2025-03-02 22:24:42.383 INFO target tracked for 0 seconds
# 2025-03-02 22:24:42.384 INFO Observing scan: scan No0087
# 2025-03-02 22:24:42.385 INFO Initiating 227.616-second track on target '1013+2449'
# 2025-03-02 22:24:43.643 INFO tracking target
# 2025-03-02 22:27:00.000 INFO Maser GPS offset [ns]: -192.267
# 2025-03-02 22:27:00.000 INFO Maser GPS offset [ns]: -192.267
# 2025-03-02 22:28:00.000 INFO Maser GPS offset [ns]: -192.262
# 2025-03-02 22:28:31.360 INFO target tracked for 227.615864038 seconds
# 2025-03-02 22:28:31.384 INFO New compound scan: 'scan No0088'
# 2025-03-02 22:28:31.385 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 22:28:33.769 INFO slewing to target
# 2025-03-02 22:28:42.495 INFO target reached
# 2025-03-02 22:28:42.501 INFO tracking target
# 2025-03-02 22:28:42.502 INFO target tracked for 0 seconds
# 2025-03-02 22:28:42.503 INFO Observing scan: scan No0088
# 2025-03-02 22:28:42.503 INFO Initiating 197.497-second track on target 'J1029A'
# 2025-03-02 22:28:43.817 INFO tracking target
# 2025-03-02 22:29:00.000 INFO Maser GPS offset [ns]: -192.258
# 2025-03-02 22:30:00.000 INFO Maser GPS offset [ns]: -192.254
# 2025-03-02 22:31:00.000 INFO Maser GPS offset [ns]: -192.235
# 2025-03-02 22:32:00.000 INFO Maser GPS offset [ns]: -192.231
# 2025-03-02 22:32:01.441 INFO target tracked for 197.496880054 seconds
# 2025-03-02 22:32:01.501 INFO New compound scan: 'scan No0089'
# 2025-03-02 22:32:01.503 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:32:03.578 INFO slewing to target
# 2025-03-02 22:32:12.288 INFO target reached
# 2025-03-02 22:32:12.293 INFO tracking target
# 2025-03-02 22:32:12.294 INFO target tracked for 0 seconds
# 2025-03-02 22:32:12.295 INFO Observing scan: scan No0089
# 2025-03-02 22:32:12.296 INFO Initiating 107.705-second track on target '1013+2449'
# 2025-03-02 22:32:13.644 INFO tracking target
# 2025-03-02 22:33:00.000 INFO Maser GPS offset [ns]: -192.226
# 2025-03-02 22:34:00.000 INFO Maser GPS offset [ns]: -192.222
# 2025-03-02 22:34:01.449 INFO target tracked for 107.70452404 seconds
# 2025-03-02 22:34:01.482 INFO New compound scan: 'scan No0090'
# 2025-03-02 22:34:01.483 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 22:34:03.861 INFO slewing to target
# 2025-03-02 22:34:12.622 INFO target reached
# 2025-03-02 22:34:12.627 INFO tracking target
# 2025-03-02 22:34:12.628 INFO target tracked for 0 seconds
# 2025-03-02 22:34:12.629 INFO Observing scan: scan No0090
# 2025-03-02 22:34:12.630 INFO Initiating 197.37-second track on target 'J1029A'
# 2025-03-02 22:34:13.883 INFO tracking target
# 2025-03-02 22:35:00.000 INFO Maser GPS offset [ns]: -192.217
# 2025-03-02 22:36:00.000 INFO Maser GPS offset [ns]: -192.213
# 2025-03-02 22:37:00.000 INFO Maser GPS offset [ns]: -192.209
# 2025-03-02 22:37:30.000 INFO Maser GPS offset [ns]: -192.206
# 2025-03-02 22:37:31.257 INFO target tracked for 197.370479107 seconds
# 2025-03-02 22:37:31.276 INFO New compound scan: 'scan No0091'
# 2025-03-02 22:37:31.277 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 22:37:33.986 INFO slewing to target
# 2025-03-02 22:37:42.743 INFO target reached
# 2025-03-02 22:37:42.749 INFO tracking target
# 2025-03-02 22:37:42.750 INFO target tracked for 0 seconds
# 2025-03-02 22:37:42.751 INFO Observing scan: scan No0091
# 2025-03-02 22:37:42.752 INFO Initiating 227.249-second track on target '1013+2449'
# 2025-03-02 22:37:44.068 INFO tracking target
# 2025-03-02 22:40:00.000 INFO Maser GPS offset [ns]: -192.196
# 2025-03-02 22:40:00.000 INFO Maser GPS offset [ns]: -192.196
# 2025-03-02 22:41:00.000 INFO Maser GPS offset [ns]: -192.191
# 2025-03-02 22:41:31.417 INFO target tracked for 227.248579979 seconds
# 2025-03-02 22:41:31.441 INFO New compound scan: 'scan No0092'
# 2025-03-02 22:41:31.442 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 22:41:34.098 INFO slewing to target
# 2025-03-02 22:41:42.858 INFO target reached
# 2025-03-02 22:41:42.864 INFO tracking target
# 2025-03-02 22:41:42.865 INFO target tracked for 0 seconds
# 2025-03-02 22:41:42.866 INFO Observing scan: scan No0092
# 2025-03-02 22:41:42.867 INFO Initiating 197.133-second track on target 'J1029B'
# 2025-03-02 22:41:44.277 INFO tracking target
# 2025-03-02 22:42:00.000 INFO Maser GPS offset [ns]: -192.187
# 2025-03-02 22:43:00.000 INFO Maser GPS offset [ns]: -192.182
# ...
# 2025-03-02 23:16:30.000 INFO Maser GPS offset [ns]: -192.005
# 2025-03-02 23:16:31.514 INFO target tracked for 197.167013884 seconds
# 2025-03-02 23:16:31.533 INFO New compound scan: 'scan No0103'
# 2025-03-02 23:16:31.534 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:16:33.799 INFO slewing to target
# 2025-03-02 23:16:42.575 INFO target reached
# 2025-03-02 23:16:42.580 INFO tracking target
# 2025-03-02 23:16:42.581 INFO target tracked for 0 seconds
# 2025-03-02 23:16:42.582 INFO Observing scan: scan No0103
# 2025-03-02 23:16:42.583 INFO Initiating 227.418-second track on target '1013+2449'
# 2025-03-02 23:16:43.952 INFO tracking target
# 2025-03-02 23:19:00.000 INFO Maser GPS offset [ns]: -191.994
# 2025-03-02 23:19:00.000 INFO Maser GPS offset [ns]: -191.994
# 2025-03-02 23:20:00.000 INFO Maser GPS offset [ns]: -191.989
# 2025-03-02 23:20:31.413 INFO target tracked for 227.417566061 seconds
# 2025-03-02 23:20:31.448 INFO New compound scan: 'scan No0104'
# 2025-03-02 23:20:31.449 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 23:20:33.768 INFO slewing to target
# 2025-03-02 23:20:42.480 INFO target reached
# 2025-03-02 23:20:42.485 INFO tracking target
# 2025-03-02 23:20:42.486 INFO target tracked for 0 seconds
# 2025-03-02 23:20:42.487 INFO Observing scan: scan No0104
# 2025-03-02 23:20:42.488 INFO Initiating 197.512-second track on target 'J1029A'
# 2025-03-02 23:20:43.841 INFO tracking target
# 2025-03-02 23:21:00.000 INFO Maser GPS offset [ns]: -191.985
# 2025-03-02 23:22:00.000 INFO Maser GPS offset [ns]: -191.98
# 2025-03-02 23:23:00.000 INFO Maser GPS offset [ns]: -191.976
# 2025-03-02 23:24:00.000 INFO Maser GPS offset [ns]: -191.971
# 2025-03-02 23:24:01.453 INFO target tracked for 197.512212992 seconds
# 2025-03-02 23:24:01.472 INFO New compound scan: 'scan No0105'
# 2025-03-02 23:24:01.473 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:24:03.774 INFO slewing to target
# 2025-03-02 23:24:12.500 INFO target reached
# 2025-03-02 23:24:12.506 INFO tracking target
# 2025-03-02 23:24:12.507 INFO target tracked for 0 seconds
# 2025-03-02 23:24:12.508 INFO Observing scan: scan No0105
# 2025-03-02 23:24:12.508 INFO Initiating 107.492-second track on target '1013+2449'
# 2025-03-02 23:24:13.854 INFO tracking target
# 2025-03-02 23:25:00.000 INFO Maser GPS offset [ns]: -191.967
# 2025-03-02 23:26:00.000 INFO Maser GPS offset [ns]: -191.962
# 2025-03-02 23:26:01.445 INFO target tracked for 107.491981983 seconds
# 2025-03-02 23:26:01.447 INFO NOTE: Phase-up correction not implemented. Continuing.
# 2025-03-02 23:26:01.448 INFO Successful phase-up correction.
# 2025-03-02 23:26:01.449 INFO Resetting re-phase timer to 1740965161.45
# 2025-03-02 23:26:01.499 INFO New compound scan: 'scan No0106'
# 2025-03-02 23:26:01.501 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 23:26:03.839 INFO slewing to target
# 2025-03-02 23:26:12.648 INFO target reached
# 2025-03-02 23:26:12.654 INFO tracking target
# 2025-03-02 23:26:12.655 INFO target tracked for 0 seconds
# 2025-03-02 23:26:12.655 INFO Observing scan: scan No0106
# 2025-03-02 23:26:12.656 INFO Initiating 197.344-second track on target 'J1029A'
# 2025-03-02 23:26:14.134 INFO tracking target
# 2025-03-02 23:27:00.000 INFO Maser GPS offset [ns]: -191.958
# 2025-03-02 23:28:00.000 INFO Maser GPS offset [ns]: -191.953
# 2025-03-02 23:29:00.000 INFO Maser GPS offset [ns]: -191.949
# 2025-03-02 23:29:30.000 INFO Maser GPS offset [ns]: -191.947
# 2025-03-02 23:29:31.577 INFO target tracked for 197.344048023 seconds
# 2025-03-02 23:29:31.595 INFO New compound scan: 'scan No0107'
# 2025-03-02 23:29:31.596 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:29:33.982 INFO slewing to target
# 2025-03-02 23:29:42.743 INFO target reached
# 2025-03-02 23:29:42.748 INFO tracking target
# 2025-03-02 23:29:42.750 INFO target tracked for 0 seconds
# 2025-03-02 23:29:42.750 INFO Observing scan: scan No0107
# 2025-03-02 23:29:42.751 INFO Initiating 227.249-second track on target '1013+2449'
# 2025-03-02 23:29:44.136 INFO tracking target
# 2025-03-02 23:32:00.000 INFO Maser GPS offset [ns]: -191.93
# 2025-03-02 23:32:00.000 INFO Maser GPS offset [ns]: -191.93
# 2025-03-02 23:33:00.000 INFO Maser GPS offset [ns]: -191.925
# 2025-03-02 23:33:31.485 INFO target tracked for 227.249056101 seconds
# 2025-03-02 23:33:31.509 INFO New compound scan: 'scan No0108'
# 2025-03-02 23:33:31.510 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 23:33:34.069 INFO slewing to target
# 2025-03-02 23:33:42.880 INFO target reached
# 2025-03-02 23:33:42.885 INFO tracking target
# 2025-03-02 23:33:42.886 INFO target tracked for 0 seconds
# 2025-03-02 23:33:42.887 INFO Observing scan: scan No0108
# 2025-03-02 23:33:42.888 INFO Initiating 197.112-second track on target 'J1029B'
# 2025-03-02 23:33:44.218 INFO tracking target
# 2025-03-02 23:34:00.000 INFO Maser GPS offset [ns]: -191.921
# 2025-03-02 23:35:00.000 INFO Maser GPS offset [ns]: -191.916
# 2025-03-02 23:36:00.000 INFO Maser GPS offset [ns]: -191.912
# 2025-03-02 23:37:00.000 INFO Maser GPS offset [ns]: -191.907
# 2025-03-02 23:37:01.412 INFO target tracked for 197.112251997 seconds
# 2025-03-02 23:37:01.430 INFO New compound scan: 'scan No0109'
# 2025-03-02 23:37:01.431 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:37:03.554 INFO slewing to target
# 2025-03-02 23:37:12.312 INFO target reached
# 2025-03-02 23:37:12.318 INFO tracking target
# 2025-03-02 23:37:12.319 INFO target tracked for 0 seconds
# 2025-03-02 23:37:12.320 INFO Observing scan: scan No0109
# 2025-03-02 23:37:12.321 INFO Initiating 107.68-second track on target '1013+2449'
# 2025-03-02 23:37:13.637 INFO tracking target
# 2025-03-02 23:38:00.000 INFO Maser GPS offset [ns]: -191.903
# 2025-03-02 23:39:00.000 INFO Maser GPS offset [ns]: -191.898
# 2025-03-02 23:39:01.417 INFO target tracked for 107.679594994 seconds
# 2025-03-02 23:39:01.440 INFO New compound scan: 'scan No0110'
# 2025-03-02 23:39:01.441 INFO Initiating 0-second track on target 'J1029B'
# 2025-03-02 23:39:03.737 INFO slewing to target
# 2025-03-02 23:39:12.595 INFO target reached
# 2025-03-02 23:39:12.600 INFO tracking target
# 2025-03-02 23:39:12.601 INFO target tracked for 0 seconds
# 2025-03-02 23:39:12.602 INFO Observing scan: scan No0110
# 2025-03-02 23:39:12.603 INFO Initiating 197.397-second track on target 'J1029B'
# 2025-03-02 23:39:13.876 INFO tracking target
# 2025-03-02 23:40:00.000 INFO Maser GPS offset [ns]: -191.894
# 2025-03-02 23:41:00.000 INFO Maser GPS offset [ns]: -191.889
# 2025-03-02 23:42:00.000 INFO Maser GPS offset [ns]: -191.885
# 2025-03-02 23:42:30.000 INFO Maser GPS offset [ns]: -191.883
# 2025-03-02 23:42:31.373 INFO target tracked for 197.397074938 seconds
# 2025-03-02 23:42:31.391 INFO New compound scan: 'scan No0111'
# 2025-03-02 23:42:31.392 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:42:33.603 INFO slewing to target
# 2025-03-02 23:42:42.379 INFO target reached
# 2025-03-02 23:42:42.385 INFO tracking target
# 2025-03-02 23:42:42.386 INFO target tracked for 0 seconds
# 2025-03-02 23:42:42.387 INFO Observing scan: scan No0111
# 2025-03-02 23:42:42.388 INFO Initiating 227.613-second track on target '1013+2449'
# 2025-03-02 23:42:43.779 INFO tracking target
# 2025-03-02 23:45:00.000 INFO Maser GPS offset [ns]: -191.872
# 2025-03-02 23:45:00.000 INFO Maser GPS offset [ns]: -191.872
# 2025-03-02 23:46:00.000 INFO Maser GPS offset [ns]: -191.864
# 2025-03-02 23:46:31.453 INFO target tracked for 227.612840891 seconds
# 2025-03-02 23:46:31.477 INFO New compound scan: 'scan No0112'
# 2025-03-02 23:46:31.478 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 23:46:33.851 INFO slewing to target
# 2025-03-02 23:46:42.661 INFO target reached
# 2025-03-02 23:46:42.667 INFO tracking target
# 2025-03-02 23:46:42.668 INFO target tracked for 0 seconds
# 2025-03-02 23:46:42.669 INFO Observing scan: scan No0112
# 2025-03-02 23:46:42.670 INFO Initiating 197.331-second track on target 'J1029A'
# 2025-03-02 23:46:43.919 INFO tracking target
# 2025-03-02 23:47:00.000 INFO Maser GPS offset [ns]: -191.859
# 2025-03-02 23:48:00.000 INFO Maser GPS offset [ns]: -191.855
# 2025-03-02 23:49:00.000 INFO Maser GPS offset [ns]: -191.85
# 2025-03-02 23:50:00.000 INFO Maser GPS offset [ns]: -191.846
# 2025-03-02 23:50:01.325 INFO target tracked for 197.330744028 seconds
# 2025-03-02 23:50:01.343 INFO New compound scan: 'scan No0113'
# 2025-03-02 23:50:01.344 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:50:03.846 INFO slewing to target
# 2025-03-02 23:50:12.605 INFO target reached
# 2025-03-02 23:50:12.611 INFO tracking target
# 2025-03-02 23:50:12.612 INFO target tracked for 0 seconds
# 2025-03-02 23:50:12.613 INFO Observing scan: scan No0113
# 2025-03-02 23:50:12.614 INFO Initiating 107.387-second track on target '1013+2449'
# 2025-03-02 23:50:13.869 INFO tracking target
# 2025-03-02 23:51:00.000 INFO Maser GPS offset [ns]: -191.841
# 2025-03-02 23:52:00.000 INFO Maser GPS offset [ns]: -191.837
# 2025-03-02 23:52:01.353 INFO target tracked for 107.386759043 seconds
# 2025-03-02 23:52:01.376 INFO New compound scan: 'scan No0114'
# 2025-03-02 23:52:01.377 INFO Initiating 0-second track on target 'J1029A'
# 2025-03-02 23:52:03.873 INFO slewing to target
# 2025-03-02 23:52:12.650 INFO target reached
# 2025-03-02 23:52:12.655 INFO tracking target
# 2025-03-02 23:52:12.656 INFO target tracked for 0 seconds
# 2025-03-02 23:52:12.657 INFO Observing scan: scan No0114
# 2025-03-02 23:52:12.658 INFO Initiating 197.342-second track on target 'J1029A'
# 2025-03-02 23:52:14.053 INFO tracking target
# 2025-03-02 23:53:00.000 INFO Maser GPS offset [ns]: -191.832
# 2025-03-02 23:54:00.000 INFO Maser GPS offset [ns]: -191.828
# 2025-03-02 23:55:00.000 INFO Maser GPS offset [ns]: -191.823
# 2025-03-02 23:55:31.464 INFO target tracked for 197.342143059 seconds
# 2025-03-02 23:55:31.482 INFO New compound scan: 'scan No0115'
# 2025-03-02 23:55:31.483 INFO Initiating 0-second track on target '1013+2449'
# 2025-03-02 23:55:33.726 INFO slewing to target
# 2025-03-02 23:55:42.434 INFO target reached
# 2025-03-02 23:55:42.440 INFO tracking target
# 2025-03-02 23:55:42.441 INFO target tracked for 0 seconds
# 2025-03-02 23:55:42.441 INFO Observing scan: scan No0115
# 2025-03-02 23:55:42.442 INFO Initiating 107.558-second track on target '1013+2449'
# 2025-03-02 23:55:43.767 INFO tracking target
# 2025-03-02 23:56:00.000 INFO Maser GPS offset [ns]: -191.819
# 2025-03-02 23:57:00.000 INFO Maser GPS offset [ns]: -191.814
# 2025-03-02 23:57:31.381 INFO target tracked for 107.558082104 seconds
# 2025-03-02 23:57:31.383 INFO Scans Observed:
# 2025-03-02 23:57:31.384 INFO - scan cal00: J0408-6545 for 319.4 sec
# 2025-03-02 23:57:31.385 INFO - scan No0035: 1013+2449 for 176.5 sec
# 2025-03-02 23:57:31.385 INFO - scan No0036: G2 for 197.3 sec
# 2025-03-02 23:57:31.386 INFO - scan No0037: 1013+2449 for 227.7 sec
# 2025-03-02 23:57:31.387 INFO - scan No0038: J1029A for 197.9 sec
# 2025-03-02 23:57:31.388 INFO - scan No0039: 1013+2449 for 107.6 sec
# 2025-03-02 23:57:31.389 INFO - scan No0040: J1029A for 198.0 sec
# 2025-03-02 23:57:31.390 INFO - scan No0041: 1013+2449 for 227.6 sec
# 2025-03-02 23:57:31.391 INFO - scan No0042: J1029B for 198.0 sec
# 2025-03-02 23:57:31.392 INFO - scan No0043: 1013+2449 for 107.7 sec
# 2025-03-02 23:57:31.393 INFO - scan No0044: J1029B for 197.9 sec
# 2025-03-02 23:57:31.394 INFO - scan No0045: 1013+2449 for 227.5 sec
# 2025-03-02 23:57:31.395 INFO - scan No0046: J1029A for 197.8 sec
# 2025-03-02 23:57:31.396 INFO - scan No0047: 1013+2449 for 107.9 sec
# 2025-03-02 23:57:31.397 INFO - scan No0048: J1029A for 197.9 sec
# 2025-03-02 23:57:31.398 INFO - scan No0049: 1013+2449 for 227.8 sec
# 2025-03-02 23:57:31.398 INFO - scan No0050: J1029A for 198.1 sec
# 2025-03-02 23:57:31.399 INFO - scan No0051: 1013+2449 for 108.1 sec
# 2025-03-02 23:57:31.400 INFO - scan No0052: J1029A for 197.9 sec
# 2025-03-02 23:57:31.401 INFO - scan No0053: 1013+2449 for 227.7 sec
# 2025-03-02 23:57:31.402 INFO - scan No0054: J1029B for 198.0 sec
# 2025-03-02 23:57:31.403 INFO - scan No0055: 1013+2449 for 108.2 sec
# 2025-03-02 23:57:31.404 INFO - scan No0056: J1029B for 198.5 sec
# 2025-03-02 23:57:31.405 INFO - scan No0057: 1013+2449 for 227.8 sec
# 2025-03-02 23:57:31.406 INFO - scan No0058: J1029B for 198.1 sec
# 2025-03-02 23:57:31.407 INFO - scan No0059: 1013+2449 for 107.9 sec
# 2025-03-02 23:57:31.408 INFO - scan No0060: J1029B for 198.1 sec
# 2025-03-02 23:57:31.409 INFO - scan No0061: 1013+2449 for 228.2 sec
# 2025-03-02 23:57:31.410 INFO - scan No0062: G2 for 197.6 sec
# 2025-03-02 23:57:31.411 INFO - scan No0063: 1013+2449 for 108.5 sec
# 2025-03-02 23:57:31.412 INFO - scan No0064: G2 for 198.4 sec
# 2025-03-02 23:57:31.412 INFO - scan No0065: 1013+2449 for 228.5 sec
# 2025-03-02 23:57:31.414 INFO - scan No0066: 4C39.25 for 488.1 sec
# 2025-03-02 23:57:31.414 INFO - scan No0067: 1013+2449 for 217.7 sec
# 2025-03-02 23:57:31.415 INFO - scan No0068: J1029A for 198.1 sec
# 2025-03-02 23:57:31.416 INFO - scan No0069: 1013+2449 for 108.7 sec
# 2025-03-02 23:57:31.417 INFO - scan No0070: J1029A for 198.8 sec
# 2025-03-02 23:57:31.418 INFO - scan No0071: 1013+2449 for 228.8 sec
# 2025-03-02 23:57:31.419 INFO - scan No0072: J1029B for 198.4 sec
# 2025-03-02 23:57:31.420 INFO - scan No0073: 1013+2449 for 109.1 sec
# 2025-03-02 23:57:31.421 INFO - scan No0074: J1029B for 199.0 sec
# 2025-03-02 23:57:31.422 INFO - scan No0075: 1013+2449 for 228.9 sec
# 2025-03-02 23:57:31.423 INFO - scan No0076: J1029A for 198.4 sec
# 2025-03-02 23:57:31.423 INFO - scan No0077: 1013+2449 for 108.8 sec
# 2025-03-02 23:57:31.424 INFO - scan No0078: J1029A for 199.1 sec
# 2025-03-02 23:57:31.425 INFO - scan No0079: 1013+2449 for 109.0 sec
# 2025-03-02 23:57:31.426 INFO - scan No0080: J1029B for 199.1 sec
# 2025-03-02 23:57:31.427 INFO - scan No0081: 1013+2449 for 109.0 sec
# 2025-03-02 23:57:31.428 INFO - scan No0082: J1029B for 198.6 sec
# 2025-03-02 23:57:31.429 INFO - scan No0083: 1013+2449 for 229.0 sec
# 2025-03-02 23:57:31.430 INFO - scan No0084: J1029A for 199.0 sec
# 2025-03-02 23:57:31.430 INFO - scan No0085: 1013+2449 for 108.9 sec
# 2025-03-02 23:57:31.431 INFO - scan No0086: J1029A for 198.8 sec
# 2025-03-02 23:57:31.432 INFO - scan No0087: 1013+2449 for 229.0 sec
# 2025-03-02 23:57:31.433 INFO - scan No0088: J1029A for 198.9 sec
# 2025-03-02 23:57:31.434 INFO - scan No0089: 1013+2449 for 109.2 sec
# 2025-03-02 23:57:31.435 INFO - scan No0090: J1029A for 198.6 sec
# 2025-03-02 23:57:31.436 INFO - scan No0091: 1013+2449 for 228.7 sec
# 2025-03-02 23:57:31.436 INFO - scan No0092: J1029B for 198.6 sec
# 2025-03-02 23:57:31.437 INFO - scan No0093: 1013+2449 for 108.3 sec
# 2025-03-02 23:57:31.438 INFO - scan No0094: J1029B for 198.9 sec
# 2025-03-02 23:57:31.439 INFO - scan No0095: 1013+2449 for 229.0 sec
# 2025-03-02 23:57:31.440 INFO - scan No0096: J1029B for 199.0 sec
# 2025-03-02 23:57:31.441 INFO - scan No0097: 1013+2449 for 108.8 sec
# 2025-03-02 23:57:31.442 INFO - scan No0098: J1029B for 198.6 sec
# 2025-03-02 23:57:31.443 INFO - scan No0099: 1013+2449 for 228.4 sec
# 2025-03-02 23:57:31.443 INFO - scan No0100: G2 for 199.2 sec
# 2025-03-02 23:57:31.444 INFO - scan No0101: 1013+2449 for 108.5 sec
# 2025-03-02 23:57:31.445 INFO - scan No0102: G2 for 198.7 sec
# 2025-03-02 23:57:31.446 INFO - scan No0103: 1013+2449 for 228.8 sec
# 2025-03-02 23:57:31.447 INFO - scan No0104: J1029A for 199.0 sec
# 2025-03-02 23:57:31.448 INFO - scan No0105: 1013+2449 for 108.9 sec
# 2025-03-02 23:57:31.449 INFO - scan No0106: J1029A for 198.9 sec
# 2025-03-02 23:57:31.450 INFO - scan No0107: 1013+2449 for 228.7 sec
# 2025-03-02 23:57:31.451 INFO - scan No0108: J1029B for 198.5 sec
# 2025-03-02 23:57:31.452 INFO - scan No0109: 1013+2449 for 109.1 sec
# 2025-03-02 23:57:31.453 INFO - scan No0110: J1029B for 198.8 sec
# 2025-03-02 23:57:31.454 INFO - scan No0111: 1013+2449 for 229.1 sec
# 2025-03-02 23:57:31.455 INFO - scan No0112: J1029A for 198.7 sec
# 2025-03-02 23:57:31.456 INFO - scan No0113: 1013+2449 for 108.7 sec
# 2025-03-02 23:57:31.457 INFO - scan No0114: J1029A for 198.8 sec
# 2025-03-02 23:57:31.458 INFO - scan No0115: 1013+2449 for 108.9 sec
# 2025-03-02 23:57:32.875 INFO DONE
